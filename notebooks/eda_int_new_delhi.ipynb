# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

import os
from pprint import pprint

import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

import matplotlib.pyplot as plt
import seaborn as sns

from openaq_anomaly_prediction.config import Configuration as config
from openaq_anomaly_prediction.utils.logging import logger, ProgressLogger
from openaq_anomaly_prediction.load.openaq import client as openaq, AreaDownloader

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", 1000)
# Out:
# 01:08:26  SUCCESS |  OPENAQ: APIKEY="0942d3c2c4c9503a675043c169119ff1a9c0e8160da51bbe18caa6f470ffafc8"

# %% [markdown]
# ### Load dataset

# %% [markdown]
# #### LOAD variables (Parquet file)

# %%
df_int_file = "new_delhi_2024_measurements.int.parquet"
df_int_path = os.path.join(config.DATA_CSV_PATH, df_int_file)
# Out:
# 01:09:22  SUCCESS |  OPENAQ: APIKEY="0942d3c2c4c9503a675043c169119ff1a9c0e8160da51bbe18caa6f470ffafc8"

# %%
schema = pq.read_schema(df_int_path)
print(schema)
# print(schema.names)
# Out:
# location_id: int64
# sensor_id: int64
# name: string
# value: double
# parameter.id: int64
# parameter.name: string
# parameter.units: string
# parameter.displayName: string
# period.datetimeFrom.local: timestamp[ns, tz=+05:30]
# period.datetimeTo.local: timestamp[ns, tz=+05:30]
# period.datetimeFrom.utc: timestamp[ns, tz=UTC]
# period.datetimeTo.utc: timestamp[ns, tz=UTC]
# location.datetimeFirst.utc: timestamp[ns, tz=UTC]
# location.datetimeLast.utc: timestamp[ns, tz=UTC]
# coordinates.latitude: double
# coordinates.longitude: double
# location_name: string
# isMobile: bool
# isMonitor: bool
# country.id: int64
# country.code: string
# country.name: string
# owner.id: int64
# owner.name: string
# provider.id: int64
# provider.name: string
# coverage.expectedCount: int64
# coverage.observedCount: int64
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 3874

# %%
metadata = pq.read_metadata(df_int_path)
print(metadata)
print()

if metadata.num_row_groups > 0:
    for i in range(metadata.num_row_groups):
        print(f"Rows in row group {i}: {metadata.row_group(i).num_rows}")
# Out:
# <pyarrow._parquet.FileMetaData object at 0x78c4c67de390>
#   created_by: parquet-cpp-arrow version 22.0.0
#   num_columns: 28
#   num_rows: 42107
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 15776
#
# Rows in row group 0: 42107

# %%
df = pd.read_parquet(df_int_path)

# %% [markdown]
# #### FILTER the rows

# %%
# FILTER the raw parquet file to only include the desired rows
import pyarrow.dataset as ds

# Assuming 'date_column' is a date or timestamp column
start_date = pd.Timestamp("2024-01-01")
end_date = pd.Timestamp("2024-12-31")

# Match the exact type of the period.datetimeTo.local column
target_type = pa.timestamp("ns", tz="+05:30")
start_date_localized = start_date.tz_localize("+05:30")
end_date_localized = end_date.tz_localize("+05:30")

# Convert pandas Timestamps to PyArrow Scalars with the target type
start_scalar = pa.scalar(start_date_localized, type=target_type)
end_scalar = pa.scalar(end_date_localized, type=target_type)

date_filter = (ds.field("period.datetimeTo.local") >= start_scalar) & (
    ds.field("period.datetimeTo.local") <= end_scalar
)

filtered_table = pq.read_table(
    df_int_path,
    filters=date_filter,
    # Optional: only load the columns you actually need
    columns=[
        "location_id",
        "sensor_id",
        "name",
        "value",
        "parameter.id",
        "parameter.name",
        "parameter.units",
        "parameter.displayName",
        "period.datetimeFrom.local",
        "period.datetimeTo.local",
        "period.datetimeFrom.utc",
        "period.datetimeTo.utc",
        # "location.datetimeFirst.utc",
        # "location.datetimeLast.utc",
        "coordinates.latitude",
        "coordinates.longitude",
        # "location_name",
        "isMobile",
        "isMonitor",
        # "country.id",
        # "country.code",
        # "country.name",
        # "owner.id",
        "owner.name",
        # "provider.id",
        "provider.name",
        # "coverage.expectedCount",
        # "coverage.observedCount",
    ],
)

# Convert the filtered result to a pandas DataFrame
filtered_df = filtered_table.to_pandas()
filtered_df.shape
# Out:
# (41876, 18)

# %%
filtered_df.head(5)
# Out:
#    location_id  sensor_id        name  value  parameter.id parameter.name parameter.units parameter.displayName period.datetimeFrom.local   period.datetimeTo.local   period.datetimeFrom.utc     period.datetimeTo.utc  coordinates.latitude  coordinates.longitude  isMobile  isMonitor                         owner.name provider.name
# 0         8118      23534  pm25 µg/m³  199.0             2           pm25           µg/m³                 PM2.5 2024-01-01 05:00:00+05:30 2024-01-01 06:00:00+05:30 2023-12-31 23:30:00+00:00 2024-01-01 00:30:00+00:00              28.63576               77.22445     False       True  Unknown Governmental Organization        AirNow
# 1         8118      23534  pm25 µg/m³  197.0             2           pm25           µg/m³                 PM2.5 2024-01-01 06:00:00+05:30 2024-01-01 07:00:00+05:30 2024-01-01 00:30:00+00:00 2024-01-01 01:30:00+00:00              28.63576               77.22445     False       True  Unknown Governmental Organization        AirNow
# 2         8118      23534  pm25 µg/m³  194.0             2           pm25           µg/m³                 PM2.5 2024-01-01 07:00:00+05:30 2024-01-01 08:00:00+05:30 2024-01-01 01:30:00+00:00 2024-01-01 02:30:00+00:00              28.63576               77.22445     False       True  Unknown Governmental Organization        AirNow
# 3         8118      23534  pm25 µg/m³  179.0             2           pm25           µg/m³                 PM2.5 2024-01-01 08:00:00+05:30 2024-01-01 09:00:00+05:30 2024-01-01 02:30:00+00:00 2024-01-01 03:30:00+00:00              28.63576               77.22445     False       True  Unknown Governmental Organization        AirNow
# 4         8118      23534  pm25 µg/m³  180.0             2           pm25           µg/m³                 PM2.5 2024-01-01 09:00:00+05:30 2024-01-01 10:00:00+05:30 2024-01-01 03:30:00+00:00 2024-01-01 04:30:00+00:00              28.63576               77.22445     False       True  Unknown Governmental Organization        AirNow

# %% [markdown]
# ### Test pollutant coverage

# %%
# PREP: Identify top pollutants by number of unique locations measuring them

KEEP_TOP_N_POLLUTANTS = 12

title = "IDENTIFYING TOP POLLUTANTS BY NUMBER OF UNIQUE LOCATIONS MEASURING THEM"
print(f"{'='*len(title)}\n{title}\n")

print(f"Unique sensors: {filtered_df['sensor_id'].nunique()}")

print("\nNumber of unique locations measuring each parameter:")
unique_locations_groupby_name = filtered_df.groupby(["name"])["location_id"].nunique().sort_values(ascending=False)

print(unique_locations_groupby_name[:KEEP_TOP_N_POLLUTANTS])  # count() or size()
top_pollutants_name = unique_locations_groupby_name[:KEEP_TOP_N_POLLUTANTS].index.tolist()

message = f"\nTop {KEEP_TOP_N_POLLUTANTS} pollutants by number of unique locations: {top_pollutants_name}"
print(f"{message}\n{'_'*len(title)}")
# Out:
# =======================================================================
# IDENTIFYING TOP POLLUTANTS BY NUMBER OF UNIQUE LOCATIONS MEASURING THEM
#
# Unique sensors: 8
#
# Number of unique locations measuring each parameter:
# name
# pm25 µg/m³             3
# pm1 µg/m³              1
# pm10 µg/m³             1
# relativehumidity %     1
# temperature c          1
# um003 particles/cm³    1
# Name: location_id, dtype: int64
#
# Top 12 pollutants by number of unique locations: ['pm25 µg/m³', 'pm1 µg/m³', 'pm10 µg/m³', 'relativehumidity %', 'temperature c', 'um003 particles/cm³']
# _______________________________________________________________________

# %%
# TEST 1: for each location of the least common pollutant, see which pollutants are measured there

title = "POLLUTANTS COVERAGE FOR ALL LOCATIONS MEASURING THE LEAST COMMON POLLUTANT"
print(f"{'='*len(title)}\n{title}\n")
total_pollutants = len(top_pollutants_name)
least_common_pollutant = top_pollutants_name[-1]
least_common_pollutant_locations = filtered_df[filtered_df["name"] == least_common_pollutant]["location_id"].unique()

print(f"Checking every location ({len(least_common_pollutant_locations)}) measuring the least common pollutant ({least_common_pollutant}) to see if they also measure all top pollutants ({total_pollutants}):")
print(top_pollutants_name)
print()

full_locations = []
partial_locations = []
id_max_length = max(len(str(id)) for id in least_common_pollutant_locations)
for location in least_common_pollutant_locations:
    df_location = filtered_df[filtered_df["location_id"] == location]
    measured_parameters = df_location["name"].unique().tolist()
    overlap = set(measured_parameters).intersection(set(top_pollutants_name))
    if len(overlap) < total_pollutants:
        partial_locations.append(location)
        print(f"> Location {location:<{id_max_length}} : {len(overlap)}/{total_pollutants}")
    else:
        full_locations.append(location)

if len(partial_locations) == 0:
    print("=> ALL LOCATIONS MEASURE ALL TOP POLLUTANTS")

print()

message = f"Locations coverage for all of the top pollutants: {len(full_locations)/len(least_common_pollutant_locations):.2%} ({len(full_locations)}/{len(least_common_pollutant_locations)} locations)"
print(f"{message}\n{'_'*len(title)}")
# Out:
# ==========================================================================
# POLLUTANTS COVERAGE FOR ALL LOCATIONS MEASURING THE LEAST COMMON POLLUTANT
#
# Checking every location (1) measuring the least common pollutant (um003 particles/cm³) to see if they also measure all top pollutants (6):
# ['pm25 µg/m³', 'pm1 µg/m³', 'pm10 µg/m³', 'relativehumidity %', 'temperature c', 'um003 particles/cm³']
#
# => ALL LOCATIONS MEASURE ALL TOP POLLUTANTS
#
# Locations coverage for all of the top pollutants: 100.00% (1/1 locations)
# __________________________________________________________________________

# %%
# FILTER the dataframe to only include measurements from locations that measure all top pollutants
selected_locations = full_locations  # only location with full coverage (all top pollutants measured)
# selected_locations = least_common_pollutant_locations  # all locations measured by the least common pollutant

selected_df = filtered_df[(filtered_df["location_id"].isin(selected_locations)) & (filtered_df["name"].isin(top_pollutants_name))]

# %%
# TEST 2.1: For each location, how much % of the total hours do they cover with measurements

# title = f"MEASUREMENTS COVERAGE (%hours) PER SELECTED LOCATION OVER THE WHOLE PERIOD (24*365={24*365} hours)"
# print(f"{'=' * len(title)}\n{title}\n")

# measurements_by_location
# for selected_df in selected_df.groupby("location_id"):

selected_df["name"].value_counts()

hourly_index = pd.date_range(
    start=pd.Timestamp("2025-01-01").tz_localize("+05:30"),
    end=pd.Timestamp("2025-12-31").tz_localize("+05:30"),
    freq='h'
)
number_of_hours = len(hourly_index)

print(f"\nTotal number of hours in the period: {number_of_hours}\n")

id_max_length = max(len(str(id)) for id in selected_locations)
name_max_length = max(len(str(name)) for name in top_pollutants_name)
for location in selected_locations:
    df_location = selected_df[selected_df["location_id"] == location]

    print(f"[Location {location}]")
    # print(f"[Location {location:<{id_max_length}}]")

    for pollutant in top_pollutants_name:
        df_location_pollutant = df_location[df_location["name"] == pollutant]
        print(f"  - {pollutant:<{name_max_length}} : {len(df_location_pollutant) / number_of_hours:>7.2%} | {len(df_location_pollutant)}/{number_of_hours}")
    print()
# Out:
# Total number of hours in the period: 8737
#
# Location 17      : 6678 unique measurement hours 46089
#   - pm25 µg/m³ :  75.68% | 6612/8737
#   - pm10 µg/m³ :  74.83% | 6538/8737
#   - o3 µg/m³   :  75.28% | 6577/8737
#   - no2 ppb    :  75.60% | 6605/8737
#   - no ppb     :  76.06% | 6645/8737
#   - co ppb     :  73.98% | 6464/8737
#   - nox ppb    :  76.09% | 6648/8737
#
# Location 8475    : 6815 unique measurement hours 46725
#   - pm25 µg/m³ :  76.73% | 6704/8737
#   - pm10 µg/m³ :  77.37% | 6760/8737
#   - o3 µg/m³   :  72.93% | 6372/8737
#   - no2 ppb    :  77.17% | 6742/8737
#   - no ppb     :  77.17% | 6742/8737
#   - co ppb     :  76.25% | 6662/8737
#   - nox ppb    :  77.18% | 6743/8737
#
# Location 10919   : 6708 unique measurement hours 45867
#   - pm25 µg/m³ :  75.99% | 6639/8737
#   - pm10 µg/m³ :  76.32% | 6668/8737
#   - o3 µg/m³   :  73.30% | 6404/8737
#   - no2 ppb    :  75.45% | 6592/8737
#   - no ppb     :  75.48% | 6595/8737
#   - co ppb     :  72.89% | 6368/8737
#   - nox ppb    :  75.55% | 6601/8737
#
# Location 5626    : 6801 unique measurement hours 47628
#   - pm25 µg/m³ :  77.88% | 6804/8737
#   - pm10 µg/m³ :  77.88% | 6804/8737
#   - o3 µg/m³   :  77.88% | 6804/8737
#   - no2 ppb    :  77.88% | 6804/8737
#   - no ppb     :  77.88% | 6804/8737
#   - co ppb     :  77.88% | 6804/8737
#   - nox ppb    :  77.88% | 6804/8737
#
# Location 10820   : 1981 unique measurement hours 8286
#   - pm25 µg/m³ :  12.33% | 1077/8737
#   - pm10 µg/m³ :  12.38% | 1082/8737
#   - o3 µg/m³   :  12.42% | 1085/8737
#   - no2 ppb    :  12.85% | 1123/8737
#   - no ppb     :  12.40% | 1083/8737
#   - co ppb     :  14.08% | 1230/8737
#   - nox ppb    :  18.38% | 1606/8737
#
# Location 6358    : 6679 unique measurement hours 45807
#   - pm25 µg/m³ :  74.99% | 6552/8737
#   - o3 µg/m³   :  18.72% | 1636/8737
#   - no2 ppb    :  18.72% | 1636/8737
#   - no ppb     :  18.71% | 1635/8737
#   - co ppb     :  18.72% | 1636/8737
#   - nox ppb    :  18.71% | 1635/8737
#
# Location 6949    : 1466 unique measurement hours 9767
#   - pm25 µg/m³ :  16.78% | 1466/8737
#   - pm10 µg/m³ :  16.78% | 1466/8737
#   - o3 µg/m³   :  16.78% | 1466/8737
#   - no2 ppb    :  14.89% | 1301/8737
#   - no ppb     :  14.89% | 1301/8737
#   - co ppb     :  16.78% | 1466/8737
#   - nox ppb    :  14.89% | 1301/8737
#
# Location 6972    : 1483 unique measurement hours 10363
#   - pm25 µg/m³ :  16.95% | 1481/8737
#   - pm10 µg/m³ :  16.94% | 1480/8737
#   - o3 µg/m³   :  16.94% | 1480/8737
#   - no2 ppb    :  16.95% | 1481/8737
#   - no ppb     :  16.96% | 1482/8737
#   - co ppb     :  16.93% | 1479/8737
#   - nox ppb    :  16.94% | 1480/8737

# %%
# TEST 2.2: for each pollutant, how many measurements (rows) do we have for the selected locations
# We already selected locations measuring all top pollutants with large coverage

# Just to have an idea of how many hours have low measurement counts
LOW_MEASUREMENT_COUNT_THRESHOLD = 40

title = f"NUMBER OF MEASUREMENTS PER POLLUTANT FOR SELECTED LOCATIONS ({selected_df['location_id'].nunique()})"
print(f"{'=' * len(title)}\n{title}\n")

unique_hours = selected_df["period.datetimeTo.local"].nunique()
name_max_length = max(len(str(name)) for name in top_pollutants_name)
for i, pollutant in enumerate(top_pollutants_name):
    df_pollutant = selected_df[selected_df["name"] == pollutant]
    df_pollutant_by_datetime = df_pollutant.groupby("period.datetimeTo.local")["value"].count().reset_index()

    MASK_DATE_FILTER = pd.Series(True, index=df_pollutant_by_datetime.index)  # default: no filter
    # MASK_DATE_FILTER = (df_pollutant_by_datetime["period.datetimeTo.local"] >= "2025-03-01") & (df_pollutant_by_datetime["period.datetimeTo.local"] < "2025-05-01")

    print(f"{'-' * len(title)}\n[{pollutant.upper()}]: {df_pollutant.shape[0]} measurements")
    measurements_low_count = df_pollutant_by_datetime[df_pollutant_by_datetime["value"] < LOW_MEASUREMENT_COUNT_THRESHOLD].shape[0]
    print(f"> Number of hours with low measurement counts (<{LOW_MEASUREMENT_COUNT_THRESHOLD}): {measurements_low_count/unique_hours:.2%} ({measurements_low_count}/{unique_hours})")
    

    fig, ax =plt.subplots(1, 1, figsize=(10, 3))
    sns.lineplot(data=df_pollutant_by_datetime[MASK_DATE_FILTER], x="period.datetimeTo.local", y="value", ax=ax)
    ax.set_title(f"Pollutant: {pollutant} (Hourly Measurements Count)")
    ax.set_xlabel("Date")
    ax.set_ylabel("Measurements Count")
    plt.tight_layout()
    plt.show()

# message = f"Locations coverage for all of the top pollutants: {full_locations_count/len(least_common_pollutant_locations):.2%} ({full_locations_count}/{len(least_common_pollutant_locations)} locations)"
# print(f"{message}\n{'_'*len(title)}")
# Out:
# ================================================================
# NUMBER OF MEASUREMENTS PER POLLUTANT FOR SELECTED LOCATIONS (62)
#
# ----------------------------------------------------------------
# [PM25 ΜG/M³]: 361660 measurements
# > Number of hours with low measurement counts (<40): 1.94% (136/6996)
# ----------------------------------------------------------------
# [PM10 ΜG/M³]: 361542 measurements
# > Number of hours with low measurement counts (<40): 1.89% (132/6996)
# ----------------------------------------------------------------
# [O3 ΜG/M³]: 357520 measurements
# > Number of hours with low measurement counts (<40): 2.23% (156/6996)
# ----------------------------------------------------------------
# [NO2 PPB]: 359697 measurements
# > Number of hours with low measurement counts (<40): 1.93% (135/6996)
# ----------------------------------------------------------------
# [NO PPB]: 356422 measurements
# > Number of hours with low measurement counts (<40): 1.90% (133/6996)
# ----------------------------------------------------------------
# [CO PPB]: 355469 measurements
# > Number of hours with low measurement counts (<40): 2.04% (143/6996)
# ----------------------------------------------------------------
# [NOX PPB]: 360911 measurements
# > Number of hours with low measurement counts (<40): 1.92% (134/6996)

# %% [markdown]
# #### Archives

# %%
# OVERLAP of each pollutant with each others

# TODO: Test ONLY the unique locations of the least common pollutant
# but test 

# Either jsut this one:
# least_common_pollutant_locations = filtered_df[filtered_df["name"] == least_common_pollutant]["location_id"].unique()
# # or the tested_pollutant_locations
# print(len(least_common_pollutant_locations))

name_max_length = max(len(name) for name in top_pollutants_name)
for pollutant in top_pollutants_name:
    tested_pollutant = pollutant
    tested_pollutant_locations = filtered_df[filtered_df["name"] == tested_pollutant]["location_id"].unique()
    other_pollutants = [p for p in top_pollutants_name if p != tested_pollutant]


    # print(f"Tested pollutant: {tested_pollutant}")
    print(f"[TESTING: {tested_pollutant.upper()} LOCATIONS ({len(tested_pollutant_locations)}) : Testing overlap of each pollutant with the tested pollutant:")
    print(f"  Other pollutants: {other_pollutants}")
    for other in other_pollutants:
        pollutant_locations = filtered_df[filtered_df["name"] == other]["location_id"].unique()

        common_locations = set(tested_pollutant_locations).intersection(set(pollutant_locations))
        print(f"  {other:<{name_max_length}} : {len(common_locations)/len(tested_pollutant_locations):>7.2%} ({len(common_locations)}/{len(tested_pollutant_locations)})")
    print()
# Out:
# [TESTING: PM25 ΜG/M³ LOCATIONS (72) : Testing overlap of each pollutant with the tested pollutant:
#   Other pollutants: ['pm10 µg/m³', 'o3 µg/m³', 'no2 ppb', 'nox ppb', 'co ppb', 'no ppb']
#   pm10 µg/m³ :  88.89% (64/72)
#   o3 µg/m³   :  87.50% (63/72)
#   no2 ppb    :  87.50% (63/72)
#   nox ppb    :  86.11% (62/72)
#   co ppb     :  86.11% (62/72)
#   no ppb     :  84.72% (61/72)
#
# [TESTING: PM10 ΜG/M³ LOCATIONS (64) : Testing overlap of each pollutant with the tested pollutant:
#   Other pollutants: ['pm25 µg/m³', 'o3 µg/m³', 'no2 ppb', 'nox ppb', 'co ppb', 'no ppb']
#   pm25 µg/m³ : 100.00% (64/64)
#   o3 µg/m³   :  98.44% (63/64)
#   no2 ppb    :  98.44% (63/64)
#   nox ppb    :  96.88% (62/64)
#   co ppb     :  96.88% (62/64)
#   no ppb     :  95.31% (61/64)
#
# [TESTING: O3 ΜG/M³ LOCATIONS (63) : Testing overlap of each pollutant with the tested pollutant:
#   Other pollutants: ['pm25 µg/m³', 'pm10 µg/m³', 'no2 ppb', 'nox ppb', 'co ppb', 'no ppb']
#   pm25 µg/m³ : 100.00% (63/63)
#   pm10 µg/m³ : 100.00% (63/63)
#   no2 ppb    :  98.41% (62/63)
#   nox ppb    :  98.41% (62/63)
#   co ppb     :  98.41% (62/63)
#   no ppb     :  96.83% (61/63)
#
# [TESTING: NO2 PPB LOCATIONS (63) : Testing overlap of each pollutant with the tested pollutant:
#   Other pollutants: ['pm25 µg/m³', 'pm10 µg/m³', 'o3 µg/m³', 'nox ppb', 'co ppb', 'no ppb']
#   pm25 µg/m³ : 100.00% (63/63)
#   pm10 µg/m³ : 100.00% (63/63)
#   o3 µg/m³   :  98.41% (62/63)
#   nox ppb    :  98.41% (62/63)
#   co ppb     :  98.41% (62/63)
#   no ppb     :  96.83% (61/63)
#
# [TESTING: NOX PPB LOCATIONS (62) : Testing overlap of each pollutant with the tested pollutant:
#   Other pollutants: ['pm25 µg/m³', 'pm10 µg/m³', 'o3 µg/m³', 'no2 ppb', 'co ppb', 'no ppb']
#   pm25 µg/m³ : 100.00% (62/62)
#   pm10 µg/m³ : 100.00% (62/62)
#   o3 µg/m³   : 100.00% (62/62)
#   no2 ppb    : 100.00% (62/62)
#   co ppb     : 100.00% (62/62)
#   no ppb     :  98.39% (61/62)
#
# [TESTING: CO PPB LOCATIONS (62) : Testing overlap of each pollutant with the tested pollutant:
#   Other pollutants: ['pm25 µg/m³', 'pm10 µg/m³', 'o3 µg/m³', 'no2 ppb', 'nox ppb', 'no ppb']
#   pm25 µg/m³ : 100.00% (62/62)
#   pm10 µg/m³ : 100.00% (62/62)
#   o3 µg/m³   : 100.00% (62/62)
#   no2 ppb    : 100.00% (62/62)
#   nox ppb    : 100.00% (62/62)
#   no ppb     :  98.39% (61/62)
#
# [TESTING: NO PPB LOCATIONS (61) : Testing overlap of each pollutant with the tested pollutant:
#   Other pollutants: ['pm25 µg/m³', 'pm10 µg/m³', 'o3 µg/m³', 'no2 ppb', 'nox ppb', 'co ppb']
#   pm25 µg/m³ : 100.00% (61/61)
#   pm10 µg/m³ : 100.00% (61/61)
#   o3 µg/m³   : 100.00% (61/61)
#   no2 ppb    : 100.00% (61/61)
#   nox ppb    : 100.00% (61/61)
#   co ppb     : 100.00% (61/61)

# %%
# Test if one of the locations measuring um003 actually measures all metrics

location_to_test = unique_locations_tested[4]
df_location = filtered_df[filtered_df["location_id"] == location_to_test]
measured_parameters = df_location["name"].unique().tolist()
print(f"Location ID {location_to_test} measures the following parameters: {measured_parameters}")
# Out:
# Location ID 4663956 measures the following parameters: ['pm1 µg/m³', 'relativehumidity %', 'um003 particles/cm³', 'pm25 µg/m³', 'temperature c']

# %%
pollutants_dict = {}

# Get the unique locations list for each pollutant
for pollutant in top_pollutants_name:
    unique_locations = filtered_df[filtered_df["name"] == pollutant]["location_id"].unique()
    pollutants_dict[pollutant] = unique_locations
    # pollutants_dict[pollutant] = len(unique_locations)
    # print(f"{pollutant}: {len(unique_locations)} unique locations")

# print()
# print(pollutants_dict)

# Compare each pollutant's unique locations with pm25 unique locations to find overlaps
for pollutant in top_pollutants_name:
    if pollutant == "pm25 µg/m³":
        continue  # Skip comparison with itself
    unique_locations = pollutants_dict[pollutant]
    overlap = set(unique_locations_pm25).intersection(set(unique_locations))
    print(f"Overlap between pm25 µg/m³ and {pollutant}: {len(overlap)/len(unique_locations):.2%} ({len(overlap)}/{len(unique_locations)} locations)")
# Out:
# Overlap between pm25 µg/m³ and pm10 µg/m³: 100.00% (64/64 locations)
# Overlap between pm25 µg/m³ and o3 µg/m³: 100.00% (63/63 locations)
# Overlap between pm25 µg/m³ and no2 ppb: 100.00% (63/63 locations)
# Overlap between pm25 µg/m³ and nox ppb: 100.00% (62/62 locations)
# Overlap between pm25 µg/m³ and co ppb: 100.00% (62/62 locations)
# Overlap between pm25 µg/m³ and no ppb: 100.00% (61/61 locations)
# Overlap between pm25 µg/m³ and relativehumidity %: 100.00% (60/60 locations)
# Overlap between pm25 µg/m³ and temperature c: 100.00% (60/60 locations)
# Overlap between pm25 µg/m³ and so2 ppb: 100.00% (54/54 locations)
# Overlap between pm25 µg/m³ and wind_speed m/s: 100.00% (54/54 locations)
# Overlap between pm25 µg/m³ and wind_direction deg: 100.00% (54/54 locations)
# Overlap between pm25 µg/m³ and pm1 µg/m³: 100.00% (6/6 locations)
# Overlap between pm25 µg/m³ and um003 particles/cm³: 100.00% (6/6 locations)

# %%
result_df = (
    filtered_df.groupby("name")
    .agg(station_count=('sensor_id', 'count')) # Use a tuple (new_col_name, aggregation_func)
    .sort_values(by='station_count', ascending=False)
)
display(result_df)
# Out:
#                      station_count
# name
# pm25 µg/m³                   44413
# pm10 µg/m³                   40412
# no2 ppb                      39906
# o3 µg/m³                     39613
# nox ppb                      38892
# co ppb                       38701
# no ppb                       38039
# temperature c                36031
# relativehumidity %           35987
# wind_speed m/s               33988
# so2 ppb                      33924
# wind_direction deg           33854
# pm1 µg/m³                     3000
# um003 particles/cm³           3000

# %%
filtered_df["name"].value_counts()
# Out:
# name
# pm25 µg/m³             22802
# pm10 µg/m³             20133
# o3 µg/m³               19849
# no2 ppb                19824
# nox ppb                19602
# co ppb                 19529
# no ppb                 19172
# temperature c          18983
# relativehumidity %     18982
# wind_speed m/s         17041
# so2 ppb                16999
# wind_direction deg     16910
# pm1 µg/m³               2009
# um003 particles/cm³     2009
# Name: count, dtype: int64

# %%
groupby = filtered_df.groupby(["location_id", "name"]).size().sort_values(ascending=False)
pprint(groupby)
# Out:
# location_id  name
# 6125489      temperature c          338
#              relativehumidity %     338
# 6119272      pm1 µg/m³              338
#              temperature c          338
# 2860223      pm1 µg/m³              338
#              temperature c          338
#              relativehumidity %     338
#              pm25 µg/m³             338
#              um003 particles/cm³    338
# 6125489      pm1 µg/m³              338
# 6119272      relativehumidity %     338
# 6125489      um003 particles/cm³    338
# 6119272      um003 particles/cm³    338
#              pm25 µg/m³             338
# 6125489      pm25 µg/m³             338
# 4663956      um003 particles/cm³    337
# 6145551      pm1 µg/m³              337
#              pm25 µg/m³             337
#              relativehumidity %     337
#              temperature c          337
# 4663956      pm1 µg/m³              337
# 6145551      um003 particles/cm³    337
# 4663956      temperature c          337
#              pm25 µg/m³             337
#              relativehumidity %     337
# 8118         pm25 µg/m³             336
# 5570         co ppb                 332
# 8235         no ppb                 332
# 6988         wind_speed m/s         332
# 5570         no ppb                 332
# 6988         wind_direction deg     332
#              so2 ppb                332
#              relativehumidity %     332
# 6986         wind_speed m/s         332
# 6988         o3 µg/m³               332
#              nox ppb                332
#              no ppb                 332
# 6986         temperature c          332
#              wind_direction deg     332
#              relativehumidity %     332
# 301          wind_speed m/s         332
# 6986         o3 µg/m³               332
# 301          wind_direction deg     332
#              temperature c          332
# 6986         pm10 µg/m³             332
# 6988         temperature c          332
# 5570         no2 ppb                332
#              o3 µg/m³               332
#              nox ppb                332
# 301          nox ppb                332
#              o3 µg/m³               332
#              pm10 µg/m³             332
#              pm25 µg/m³             332
# 5570         pm25 µg/m³             332
# 5586         co ppb                 332
# 301          no ppb                 332
# 5570         pm10 µg/m³             332
# 5586         no2 ppb                332
#              no ppb                 332
# 5598         relativehumidity %     332
# 8235         wind_speed m/s         332
# 5586         nox ppb                332
# 6938         relativehumidity %     332
#              so2 ppb                332
#              temperature c          332
# 5613         co ppb                 332
#              no ppb                 332
#              no2 ppb                332
#              nox ppb                332
# 6938         wind_speed m/s         332
#              no ppb                 332
#              no2 ppb                332
#              nox ppb                332
# 5586         pm10 µg/m³             332
#              pm25 µg/m³             332
#              so2 ppb                332
#              relativehumidity %     332
#              wind_direction deg     332
#              wind_speed m/s         332
# 8235         no2 ppb                332
# 5586         temperature c          332
# 8235         nox ppb                332
#              o3 µg/m³               332
#              temperature c          332
#              relativehumidity %     332
# 301          relativehumidity %     332
#              so2 ppb                332
# 5586         o3 µg/m³               332
# 301          no2 ppb                332
# 5622         nox ppb                332
#              no2 ppb                332
#              no ppb                 332
#              co ppb                 332
# 5616         pm25 µg/m³             332
#              pm10 µg/m³             332
#              o3 µg/m³               332
# 6924         wind_direction deg     332
#              temperature c          332
#              relativehumidity %     332
#              pm25 µg/m³             332
#              pm10 µg/m³             332
# 5613         o3 µg/m³               332
#              pm10 µg/m³             332
# 10919        wind_direction deg     332
#              wind_speed m/s         332
# 5622         o3 µg/m³               332
#              pm10 µg/m³             332
#              pm25 µg/m³             332
# 5598         temperature c          332
#              wind_direction deg     332
#              wind_speed m/s         332
# 6924         wind_speed m/s         332
# 5630         so2 ppb                332
#              temperature c          332
#              wind_direction deg     332
#              wind_speed m/s         332
# 10919        o3 µg/m³               332
#              pm10 µg/m³             332
#              pm25 µg/m³             332
#              relativehumidity %     332
# 5626         no ppb                 332
# 10919        temperature c          332
# 5616         nox ppb                332
#              no2 ppb                332
#              no ppb                 332
#              co ppb                 332
# 5613         so2 ppb                332
#              pm25 µg/m³             332
# 5626         wind_direction deg     332
#              temperature c          332
#              so2 ppb                332
#              relativehumidity %     332
#              pm25 µg/m³             332
#              pm10 µg/m³             332
#              o3 µg/m³               332
#              nox ppb                332
#              no2 ppb                332
#              co ppb                 332
# 5622         wind_speed m/s         332
#              wind_direction deg     332
#              temperature c          332
#              relativehumidity %     332
#              so2 ppb                332
# 5630         relativehumidity %     332
#              pm25 µg/m³             332
#              no2 ppb                332
#              pm10 µg/m³             332
#              o3 µg/m³               332
#              nox ppb                332
#              co ppb                 332
#              no ppb                 332
# 5626         wind_speed m/s         332
# 301          co ppb                 332
# 235          wind_speed m/s         331
#              wind_direction deg     331
# 50           pm25 µg/m³             331
#              relativehumidity %     331
# 235          relativehumidity %     331
#              temperature c          331
# 50           nox ppb                331
#              pm10 µg/m³             331
# 10488        pm25 µg/m³             331
# 10919        no ppb                 331
#              no2 ppb                331
#              nox ppb                331
#              so2 ppb                331
# 50           no2 ppb                331
# 10485        co ppb                 331
# 10484        wind_speed m/s         331
# 10485        no ppb                 331
#              no2 ppb                331
#              wind_speed m/s         331
# 10488        co ppb                 331
#              o3 µg/m³               331
#              pm10 µg/m³             331
# 10485        relativehumidity %     331
#              nox ppb                331
#              wind_direction deg     331
#              temperature c          331
# 10488        no ppb                 331
#              no2 ppb                331
# 8475         pm25 µg/m³             331
#              pm10 µg/m³             331
# 6931         nox ppb                331
# 8475         temperature c          331
# 8917         temperature c          331
# 8915         wind_speed m/s         331
#              temperature c          331
# 8917         relativehumidity %     331
#              o3 µg/m³               331
#              wind_direction deg     331
#              wind_speed m/s         331
# 10484        no2 ppb                331
#              nox ppb                331
#              pm10 µg/m³             331
#              pm25 µg/m³             331
#              relativehumidity %     331
#              temperature c          331
#              wind_direction deg     331
# 8915         o3 µg/m³               331
# 6931         no ppb                 331
#              co ppb                 331
# 8915         so2 ppb                331
# 8475         wind_speed m/s         331
#              wind_direction deg     331
# 6931         no2 ppb                331
# 8365         o3 µg/m³               331
#              pm10 µg/m³             331
# 6960         no ppb                 331
#              nox ppb                331
#              o3 µg/m³               331
# 6986         pm25 µg/m³             331
# 6960         pm10 µg/m³             331
# 6988         pm10 µg/m³             331
#              pm25 µg/m³             331
# 6957         pm25 µg/m³             331
# 6960         wind_speed m/s         331
#              wind_direction deg     331
#              temperature c          331
#              relativehumidity %     331
#              so2 ppb                331
# 50           temperature c          331
# 6957         nox ppb                331
# 50           wind_direction deg     331
#              wind_speed m/s         331
# 235          no2 ppb                331
#              co ppb                 331
#              nox ppb                331
#              pm10 µg/m³             331
#              pm25 µg/m³             331
# 6957         pm10 µg/m³             331
# 50           no ppb                 331
# 6957         no2 ppb                331
# 8365         nox ppb                331
#              no2 ppb                331
#              no ppb                 331
#              co ppb                 331
# 6957         no ppb                 331
#              co ppb                 331
# 6960         no2 ppb                331
# 6938         pm10 µg/m³             331
# 8365         temperature c          331
# 6938         o3 µg/m³               331
# 5598         o3 µg/m³               331
# 8365         pm25 µg/m³             331
#              wind_speed m/s         331
#              relativehumidity %     331
# 6934         temperature c          331
#              so2 ppb                331
#              relativehumidity %     331
#              pm25 µg/m³             331
#              pm10 µg/m³             331
#              nox ppb                331
#              no2 ppb                331
#              no ppb                 331
# 8475         o3 µg/m³               331
# 6931         wind_speed m/s         331
#              temperature c          331
#              wind_direction deg     331
# 6934         wind_speed m/s         331
# 6931         pm25 µg/m³             331
# 6934         wind_direction deg     331
# 6931         relativehumidity %     331
# 6938         co ppb                 330
# 5598         nox ppb                330
# 50           co ppb                 330
# 6957         o3 µg/m³               330
# 6960         co ppb                 330
# 8235         co ppb                 330
# 6986         so2 ppb                330
# 6960         pm25 µg/m³             330
# 8472         no ppb                 330
#              relativehumidity %     330
#              no2 ppb                330
#              nox ppb                330
#              temperature c          330
# 5598         so2 ppb                330
#              no ppb                 330
#              no2 ppb                330
# 10485        so2 ppb                330
# 10831        co ppb                 330
#              no2 ppb                330
#              nox ppb                330
# 10488        nox ppb                330
# 10831        so2 ppb                330
#              pm10 µg/m³             330
# 8915         pm25 µg/m³             330
# 8475         so2 ppb                330
#              nox ppb                330
# 8472         wind_direction deg     330
# 8475         no2 ppb                330
#              co ppb                 330
# 8472         wind_speed m/s         330
# 8475         no ppb                 330
# 6931         so2 ppb                330
# 8917         no2 ppb                330
#              pm10 µg/m³             330
# 6359         nox ppb                330
# 8917         nox ppb                330
# 6359         pm10 µg/m³             330
#              o3 µg/m³               330
# 8917         no ppb                 330
# 10831        no ppb                 330
#              o3 µg/m³               330
# 6359         wind_direction deg     330
# 50           o3 µg/m³               330
# 235          so2 ppb                329
# 5610         no2 ppb                329
# 10485        pm10 µg/m³             329
#              pm25 µg/m³             329
# 6359         wind_speed m/s         329
# 6932         relativehumidity %     329
#              pm25 µg/m³             329
# 6359         pm25 µg/m³             329
#              no2 ppb                329
#              co ppb                 329
#              relativehumidity %     329
# 10484        no ppb                 329
#              co ppb                 329
# 6359         temperature c          329
#              so2 ppb                329
# 5610         co ppb                 329
# 8915         pm10 µg/m³             329
# 5610         no ppb                 329
# 6932         so2 ppb                329
# 8475         relativehumidity %     329
# 6932         temperature c          329
# 5404         co ppb                 329
# 6986         co ppb                 329
# 5404         no2 ppb                329
# 3409519      temperature c          329
#              relativehumidity %     329
#              wind_direction deg     329
#              wind_speed m/s         329
# 5610         nox ppb                329
# 5541         pm25 µg/m³             329
#              pm10 µg/m³             329
#              o3 µg/m³               329
#              nox ppb                329
#              no2 ppb                329
#              co ppb                 329
# 5404         pm25 µg/m³             329
#              pm10 µg/m³             329
#              o3 µg/m³               329
#              no ppb                 329
# 6932         pm10 µg/m³             329
#              o3 µg/m³               329
#              nox ppb                329
#              no2 ppb                329
#              no ppb                 329
#              co ppb                 329
# 8472         so2 ppb                329
# 5610         pm10 µg/m³             329
# 8472         o3 µg/m³               329
#              pm10 µg/m³             329
# 5610         o3 µg/m³               329
#              pm25 µg/m³             329
# 6932         wind_speed m/s         329
#              wind_direction deg     329
# 5404         nox ppb                329
# 6358         so2 ppb                328
#              relativehumidity %     328
#              wind_direction deg     328
#              wind_speed m/s         328
# 6359         no ppb                 328
# 6924         co ppb                 328
# 6931         o3 µg/m³               328
# 6358         pm10 µg/m³             328
#              o3 µg/m³               328
#              nox ppb                328
#              no ppb                 328
#              no2 ppb                328
# 17           co ppb                 328
#              nox ppb                328
# 10831        pm25 µg/m³             328
# 17           no ppb                 328
#              no2 ppb                328
# 6358         temperature c          328
# 8365         so2 ppb                328
# 3409519      o3 µg/m³               328
#              so2 ppb                328
# 6957         wind_direction deg     328
#              wind_speed m/s         328
#              relativehumidity %     328
#              temperature c          328
# 6972         no ppb                 328
# 17           wind_speed m/s         328
#              wind_direction deg     328
#              temperature c          328
#              relativehumidity %     328
#              pm25 µg/m³             328
# 3409519      co ppb                 327
# 6972         wind_speed m/s         327
#              wind_direction deg     327
# 6986         nox ppb                327
# 6972         relativehumidity %     327
#              pm25 µg/m³             327
#              pm10 µg/m³             327
#              o3 µg/m³               327
# 6988         co ppb                 327
# 6972         co ppb                 327
#              no2 ppb                327
#              nox ppb                327
#              so2 ppb                327
#              temperature c          327
# 6988         no2 ppb                327
# 6356         wind_speed m/s         327
# 10831        temperature c          327
#              relativehumidity %     327
#              wind_direction deg     327
# 6356         nox ppb                327
#              relativehumidity %     327
#              pm25 µg/m³             327
#              pm10 µg/m³             327
# 6986         no ppb                 327
# 6934         o3 µg/m³               327
# 8917         pm25 µg/m³             327
# 6356         no2 ppb                327
# 10484        o3 µg/m³               327
# 6356         no ppb                 327
#              co ppb                 327
#              temperature c          327
# 8235         so2 ppb                327
# 10920        so2 ppb                326
#              pm10 µg/m³             326
#              pm25 µg/m³             326
# 5598         co ppb                 326
# 10920        relativehumidity %     326
# 10486        no ppb                 326
# 17           pm10 µg/m³             326
# 3409519      no2 ppb                326
#              nox ppb                326
#              pm10 µg/m³             326
# 8915         relativehumidity %     326
# 8917         so2 ppb                326
# 10920        o3 µg/m³               326
# 8235         wind_direction deg     326
# 10920        nox ppb                326
#              no2 ppb                326
#              no ppb                 326
#              temperature c          326
#              wind_direction deg     326
#              wind_speed m/s         326
# 10484        so2 ppb                326
# 10486        relativehumidity %     326
#              nox ppb                326
#              temperature c          326
#              wind_direction deg     326
#              wind_speed m/s         326
# 10920        co ppb                 326
# 10486        no2 ppb                326
# 5650         co ppb                 325
#              no ppb                 325
#              no2 ppb                325
#              nox ppb                325
# 10486        co ppb                 325
# 5650         pm10 µg/m³             325
# 10486        so2 ppb                325
#              pm10 µg/m³             325
# 5650         pm25 µg/m³             325
#              o3 µg/m³               325
# 6358         pm25 µg/m³             325
# 6938         pm25 µg/m³             325
# 10921        o3 µg/m³               324
#              pm10 µg/m³             324
#              pm25 µg/m³             324
#              nox ppb                324
# 6957         so2 ppb                324
# 10921        co ppb                 324
#              no2 ppb                324
#              no ppb                 324
# 10488        wind_direction deg     324
#              wind_speed m/s         324
#              relativehumidity %     324
#              temperature c          324
# 6924         no ppb                 324
#              no2 ppb                324
#              nox ppb                324
# 6953         wind_direction deg     324
# 17           so2 ppb                324
# 6953         wind_speed m/s         323
#              no ppb                 323
#              co ppb                 323
#              so2 ppb                323
#              relativehumidity %     323
#              temperature c          323
#              no2 ppb                323
#              o3 µg/m³               323
#              nox ppb                323
#              pm10 µg/m³             323
#              pm25 µg/m³             323
# 17           o3 µg/m³               322
# 6929         relativehumidity %     322
#              temperature c          322
#              pm10 µg/m³             322
#              no2 ppb                322
#              nox ppb                322
# 8917         co ppb                 322
# 6356         o3 µg/m³               322
# 5627         co ppb                 322
# 10831        wind_speed m/s         322
# 5627         nox ppb                322
#              pm25 µg/m³             322
#              pm10 µg/m³             322
#              o3 µg/m³               322
#              no ppb                 322
#              no2 ppb                322
# 8239         temperature c          321
#              so2 ppb                321
#              pm10 µg/m³             321
#              pm25 µg/m³             321
#              relativehumidity %     321
# 6929         no ppb                 321
# 8239         wind_direction deg     321
#              wind_speed m/s         321
# 6929         wind_speed m/s         321
#              wind_direction deg     321
#              co ppb                 321
# 6924         so2 ppb                321
# 6105800      um003 particles/cm³    321
# 8235         pm25 µg/m³             321
# 6105800      pm1 µg/m³              321
#              pm25 µg/m³             321
#              relativehumidity %     321
#              temperature c          321
# 8239         no2 ppb                320
# 6356         so2 ppb                320
# 8239         no ppb                 320
#              o3 µg/m³               320
#              nox ppb                320
# 6929         o3 µg/m³               320
# 8472         co ppb                 320
# 6929         so2 ppb                319
# 10486        pm25 µg/m³             319
# 5588         pm25 µg/m³             318
# 6978         pm25 µg/m³             318
# 5588         nox ppb                318
# 3409519      no ppb                 318
#              pm25 µg/m³             318
# 5588         no ppb                 318
#              no2 ppb                318
#              co ppb                 318
#              temperature c          318
#              relativehumidity %     318
#              so2 ppb                318
#              wind_direction deg     318
#              wind_speed m/s         318
#              o3 µg/m³               318
#              pm10 µg/m³             318
# 6978         o3 µg/m³               317
#              pm10 µg/m³             317
# 3410004      pm25 µg/m³             316
#              wind_direction deg     316
#              so2 ppb                316
#              relativehumidity %     316
#              temperature c          316
#              pm10 µg/m³             316
#              wind_speed m/s         316
#              nox ppb                316
#              no2 ppb                316
#              co ppb                 316
#              o3 µg/m³               316
# 6358         co ppb                 316
# 3410004      no ppb                 316
# 6931         pm10 µg/m³             316
# 6929         pm25 µg/m³             315
# 6978         so2 ppb                315
#              no2 ppb                315
#              nox ppb                315
# 8472         pm25 µg/m³             314
# 10488        so2 ppb                314
# 8915         co ppb                 314
# 6924         o3 µg/m³               313
# 6978         no ppb                 313
# 8915         wind_direction deg     313
# 10486        o3 µg/m³               313
# 10908        o3 µg/m³               312
# 6986         no2 ppb                312
# 235          no ppb                 312
# 10908        nox ppb                312
#              pm10 µg/m³             312
# 10485        o3 µg/m³               312
# 10908        no ppb                 312
#              pm25 µg/m³             312
# 5598         pm25 µg/m³             312
# 10908        so2 ppb                312
# 6949         pm25 µg/m³             311
# 10908        wind_speed m/s         311
#              temperature c          311
# 6949         o3 µg/m³               311
#              pm10 µg/m³             311
#              temperature c          311
#              so2 ppb                311
#              co ppb                 311
#              wind_direction deg     311
# 10908        wind_direction deg     311
#              relativehumidity %     311
#              no2 ppb                311
#              co ppb                 311
# 6949         wind_speed m/s         311
#              relativehumidity %     311
# 8235         pm10 µg/m³             310
# 11607        no2 ppb                310
#              so2 ppb                310
# 50           so2 ppb                308
# 5634         co ppb                 308
#              pm25 µg/m³             308
#              pm10 µg/m³             308
# 11607        wind_speed m/s         308
#              pm10 µg/m³             308
# 5634         nox ppb                308
#              o3 µg/m³               308
#              no ppb                 308
# 11607        wind_direction deg     308
#              temperature c          308
# 5634         no2 ppb                308
# 11607        pm25 µg/m³             307
# 3024966      pm25 µg/m³             307
# 11607        relativehumidity %     307
# 8915         nox ppb                306
#              no2 ppb                305
#              no ppb                 304
# 6356         wind_direction deg     303
# 6934         co ppb                 302
# 6978         co ppb                 301
# 10825        wind_direction deg     300
#              pm10 µg/m³             300
#              relativehumidity %     300
#              temperature c          300
#              pm25 µg/m³             300
#              wind_speed m/s         300
#              so2 ppb                300
#              o3 µg/m³               300
#              nox ppb                300
#              no2 ppb                300
#              no ppb                 300
#              co ppb                 300
# 7005         no2 ppb                299
#              co ppb                 299
#              no ppb                 298
#              wind_speed m/s         298
#              nox ppb                298
#              relativehumidity %     298
#              wind_direction deg     298
#              temperature c          298
# 235          o3 µg/m³               298
# 8319         wind_speed m/s         295
#              temperature c          295
# 5598         pm10 µg/m³             295
# 8319         relativehumidity %     295
#              wind_direction deg     295
#              o3 µg/m³               294
#              co ppb                 294
#              no2 ppb                293
# 7005         so2 ppb                293
# 8319         nox ppb                293
#              pm10 µg/m³             293
#              pm25 µg/m³             293
#              no ppb                 293
#              so2 ppb                292
# 6978         wind_direction deg     291
#              wind_speed m/s         291
#              relativehumidity %     291
#              temperature c          291
# 11603        co ppb                 287
#              pm25 µg/m³             287
#              no ppb                 287
#              so2 ppb                287
#              wind_direction deg     287
#              relativehumidity %     287
#              no2 ppb                287
# 6938         wind_direction deg     287
# 11603        o3 µg/m³               287
#              wind_speed m/s         287
#              temperature c          287
#              pm10 µg/m³             287
#              nox ppb                287
# 10919        co ppb                 283
# 7005         o3 µg/m³               282
# 6936         temperature c          278
#              so2 ppb                278
#              no ppb                 278
#              co ppb                 278
#              wind_direction deg     278
#              wind_speed m/s         278
#              nox ppb                278
#              no2 ppb                278
#              pm10 µg/m³             278
#              o3 µg/m³               278
#              pm25 µg/m³             278
#              relativehumidity %     278
# 8239         co ppb                 276
# 7005         pm25 µg/m³             269
#              pm10 µg/m³             261
# 5665         temperature c          260
#              no2 ppb                260
#              so2 ppb                260
#              o3 µg/m³               260
#              nox ppb                260
#              relativehumidity %     260
#              co ppb                 260
#              wind_speed m/s         260
#              wind_direction deg     260
#              no ppb                 260
#              pm25 µg/m³             259
#              pm10 µg/m³             259
# 10900        wind_direction deg     253
#              o3 µg/m³               251
#              wind_speed m/s         251
# 6980         o3 µg/m³               249
# 8365         wind_direction deg     249
# 10900        pm25 µg/m³             249
# 6980         co ppb                 248
#              temperature c          248
#              wind_speed m/s         248
#              wind_direction deg     248
#              relativehumidity %     248
#              so2 ppb                248
# 10900        pm10 µg/m³             244
#              relativehumidity %     243
#              temperature c          242
# 6980         pm25 µg/m³             235
#              pm10 µg/m³             235
#              nox ppb                218
#              no2 ppb                218
#              no ppb                 218
# 6949         no ppb                 206
#              no2 ppb                206
#              nox ppb                206
# 10820        wind_direction deg     161
#              wind_speed m/s         126
#              nox ppb                124
#              co ppb                  84
#              so2 ppb                 68
#              pm25 µg/m³              68
#              relativehumidity %      68
#              o3 µg/m³                64
#              temperature c           62
#              no ppb                  57
#              no2 ppb                 57
#              pm10 µg/m³              57
# dtype: int64
