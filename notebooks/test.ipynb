# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

from openaq_anomaly_prediction.config import Configuration as config
from openaq_anomaly_prediction.utils.logging import logger
from openaq_anomaly_prediction.load.openaq import OpenAQ_Client

openaq = OpenAQ_Client()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 14:52:01  SUCCESS |  OPENAQ: APIKEY=default

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pprint import pprint
from openaq import OpenAQ

# %%
from pandas import json_normalize

# %%
config.getenv("OPENAQ_API_KEY")
# Out:
# '0942d3c2c4c9503a675043c169119ff1a9c0e8160da51bbe18caa6f470ffafc8'

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000)

# %% [markdown]
# ### Functions (OpenAQ API)

# %%
import requests
from pandas import json_normalize

def request_openaq(url: str, params: dict) -> dict[str, pd.DataFrame]:

    # TODO: Add a safe-guard for rate limiting from the request headers.
    # Test the remaining requests within the limit, and if close to the limit, wait until reset.
    headers = {
        "X-API-Key": config.getenv("OPENAQ_API_KEY"),
        "accept": "application/json"
    }

    # 3. Make the Request
    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status() # Raises error for 4xx or 5xx
        
        # 4. Process Data
        data = response.json()

        # pprint(data)  # Print metadata for debugging
        # print(data['meta'])  # Print metadata for debugging

        # meta = json_normalize(data['meta'])
        results = json_normalize(data['results'])
        return { "meta": data['meta'], "results": results }

    except requests.exceptions.HTTPError as err:
        print(f"HTTP error occurred: {err}")
        print(response.text) # Print the error message from OpenAQ
        raise err

# %% [markdown]
# ### Get locations

# %%
# GET LOCATIONS WITHIN BBOX

# IMPORTANT: API requires bbox as a comma-separated string,
# not a python list/tuple when using 'requests'
bbox_list = [76.772461,28.161110,77.768372,28.943516]
bbox_str = ",".join(map(str, bbox_list))

locations = request_openaq(
    "https://api.openaq.org/v3/locations", {"bbox": bbox_str, "limit": 1000,},
)
locations.shape
# Out:
# (107, 26)

# %%
# 1 location record example
display(locations.head(1).to_dict(orient='records'))
# Out:
# [{'id': 13,
#   'name': 'Delhi Technological University, Delhi - CPCB',
#   'locality': None,
#   'timezone': 'Asia/Kolkata',
#   'isMobile': False,
#   'isMonitor': True,
#   'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#   'sensors': [{'id': 13866,
#     'name': 'no2 µg/m³',
#     'parameter': {'id': 5,
#      'name': 'no2',
#      'units': 'µg/m³',
#      'displayName': 'NO₂ mass'}},
#    {'id': 24,
#     'name': 'o3 µg/m³',
#     'parameter': {'id': 3,
#      'name': 'o3',
#      'units': 'µg/m³',
#      'displayName': 'O₃ mass'}},
#    {'id': 13864,
#     'name': 'pm25 µg/m³',
#     'parameter': {'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': 'PM2.5'}}],
#   'licenses': None,
#   'bounds': [77.12, 28.744, 77.12, 28.744],
#   'distance': None,
#   'country.id': 9,
#   'country.code': 'IN',
#   'country.name': 'India',
#   'owner.id': 4,
#   'owner.name': 'Unknown Governmental Organization',
#   'provider.id': 168,
#   'provider.name': 'CPCB',
#   'coordinates.latitude': 28.744,
#   'coordinates.longitude': 77.12,
#   'datetimeFirst.utc': '2016-11-02T19:00:00Z',
#   'datetimeFirst.local': '2016-11-03T00:30:00+05:30',
#   'datetimeLast.utc': '2018-02-22T04:00:00Z',
#   'datetimeLast.local': '2018-02-22T09:30:00+05:30',
#   'datetimeFirst': nan,
#   'datetimeLast': nan}]

# %%
locations.iloc[0]["sensors"]
# Out:
# [{'id': 13866,
#   'name': 'no2 µg/m³',
#   'parameter': {'id': 5,
#    'name': 'no2',
#    'units': 'µg/m³',
#    'displayName': 'NO₂ mass'}},
#  {'id': 24,
#   'name': 'o3 µg/m³',
#   'parameter': {'id': 3,
#    'name': 'o3',
#    'units': 'µg/m³',
#    'displayName': 'O₃ mass'}},
#  {'id': 13864,
#   'name': 'pm25 µg/m³',
#   'parameter': {'id': 2,
#    'name': 'pm25',
#    'units': 'µg/m³',
#    'displayName': 'PM2.5'}}]

# %% [markdown]
# ### Sensors Overview

# %%
# FLATTEN THE SENSORS AND THE PARAMETERS WITHIN EACH LOCATION
def flatten_sensors(row):
    flattened = [
        {
            'location_id': row.get('id'),
            'id': sensor.get('id'),
            'name': sensor.get('name'),
            'parameter_id': sensor.get('parameter', {}).get('id'),
            'parameter_name': sensor.get('parameter', {}).get('name'),
            'parameter_units': sensor.get('parameter', {}).get('units'),
            'parameter_displayName': sensor.get('parameter', {}).get('displayName'),
        }
        for sensor in row.get('sensors', [])
    ]
    return flattened

# 1. Flatten the sensors for each location
df_sensors_flat = locations.copy()
df_sensors_flat['sensors_flat'] = df_sensors_flat.apply(flatten_sensors, axis=1)

# 2. Create a new DataFrame holding every single "sensor"
df_sensors_exploded = df_sensors_flat["sensors_flat"].explode()
df_sensors = pd.DataFrame(df_sensors_exploded.tolist())
display(df_sensors.head())

# # 2.ALTERNATIVE (GEMINI): Using pd.json_normalize to directly explode and flatten nested lists all at once
# df_sensors = pd.json_normalize(
#     data=locations.to_dict(orient='records'), 
#     record_path='sensors',       # The key containing the list to explode
#     meta=['id'],                 # The parent columns to keep
#     meta_prefix='location_',     # Prefix for parent columns (id -> location_id)
#     sep='_'                      # Separator for nested keys (parameter.id -> parameter_id)
# )
# display(df_sensors.head())
# Out:
#    location_id     id        name  parameter_id parameter_name parameter_units parameter_displayName
# 0           13  13866   no2 µg/m³             5            no2           µg/m³              NO₂ mass
# 1           13     24    o3 µg/m³             3             o3           µg/m³               O₃ mass
# 2           13  13864  pm25 µg/m³             2           pm25           µg/m³                 PM2.5
# 3           15     27    co µg/m³             4             co           µg/m³               CO mass
# 4           15     28   no2 µg/m³             5            no2           µg/m³              NO₂ mass

# %%
# ANALYSE THE SENSORS DATAFRAME
parameter_column = "name"  # parameter_id | name (NOT parameter_name)

print(f"\n{'='*44}\n{'SENSORS OVERVIEW'}\n")
print(f"Unique {parameter_column}: {df_sensors.nunique().loc[parameter_column]}")
print(f"Unique location_id: {df_sensors.nunique().loc['location_id']}\n")
# display(df_sensors.nunique())

groupby = df_sensors.groupby([parameter_column, "location_id"])["location_id"].count()#.sort_values(ascending=False)
# display(groupby)
groupby = groupby.groupby([parameter_column])
# display(groupby.count())  # or groupby.value_counts()

# ---------------------------------------------------------------------
# Total number of locations per parameter_name (at least 1 sensor of that parameter)
sensors_count_total = pd.DataFrame(groupby.count().sort_values(ascending=False).reset_index()).rename(columns={"location_id": "nb_locations"})
sensors_count_total["coverage%"] = round(sensors_count_total["nb_locations"] / locations.shape[0] * 100, 2)
print(f"\n{'='*44}\n{'COVERAGE OF THE SENSORS (%TOTAL LOCATIONS)':^44}\n{'='*44}")
display(sensors_count_total)


# ---------------------------------------------------------------------
# Detailed sensor counts per location for each metric
sensors_count_per_location = pd.DataFrame(groupby.value_counts().reset_index()).rename(columns={"location_id": "count_per_location", "count": "nb_locations"})
# print(f"\n{'='*50}\n{'DISTRIBUTION OF THE SENSOR COUNT PER LOCATION':^50}\n{'='*50}")
# display(sensors_count_per_location)


# ---------------------------------------------------------------------
# Only keep sensors with more than 1 sensor per location
names_with_multiple_sensors = sensors_count_per_location[sensors_count_per_location["count_per_location"] > 1]["name"].unique()
sensors_count_with_multiple_sensors = sensors_count_per_location[sensors_count_per_location["name"].isin(names_with_multiple_sensors)].sort_values(by=["name", "count_per_location"], ascending=[True, False])
print(f"\n{'='*44}\n{'MULTIPLE SENSORS AT THE SAME LOCATION':^44}\n{'='*44}")
display(sensors_count_with_multiple_sensors)
# Out:
# ============================================
# SENSORS OVERVIEW
#
# Unique name: 18
# Unique location_id: 107
#
#
# ============================================
#  COVERAGE OF THE SENSORS (%TOTAL LOCATIONS)
# ============================================
#                    name  nb_locations  coverage%
# 0            pm25 µg/m³           105      98.13
# 1              o3 µg/m³            95      88.79
# 2            pm10 µg/m³            94      87.85
# 3             no2 µg/m³            87      81.31
# 4              co µg/m³            82      76.64
# 5             so2 µg/m³            73      68.22
# 6               no2 ppb            64      59.81
# 7                co ppb            63      58.88
# 8               nox ppb            63      58.88
# 9                no ppb            63      58.88
# 10   relativehumidity %            60      56.07
# 11        temperature c            60      56.07
# 12              so2 ppb            55      51.40
# 13   wind_direction deg            54      50.47
# 14       wind_speed m/s            54      50.47
# 15            pm1 µg/m³             6       5.61
# 16  um003 particles/cm³             6       5.61
# 17               o3 ppm             1       0.93
# ============================================
#    MULTIPLE SENSORS AT THE SAME LOCATION
# ============================================
#           name  count_per_location  nb_locations
# 7     o3 µg/m³                   2            50
# 8     o3 µg/m³                   1            45
# 10  pm10 µg/m³                   2            53
# 11  pm10 µg/m³                   1            41
# 12  pm25 µg/m³                   2            53
# 13  pm25 µg/m³                   1            52

# %% [markdown]
# #### Gemini alternative

# %%
# ---------------------------------------------------------------------
# FULL GEMINI VERSION

import pandas as pd

# Assume df_sensors is your fully flattened sensor DataFrame
# Assume locations is your original locations DataFrame
parameter_column = "name" # You can switch this to 'parameter_id' or 'parameter_name'

print(f"\n{'='*40}\n{'SENSORS OVERVIEW'}\n")
print(f"Unique {parameter_column}: {df_sensors[parameter_column].nunique()}")
print(f"Unique location_id: {df_sensors['location_id'].nunique()}\n")

# --- CORE AGGREGATION STEP ---
# Calculate the number of sensors of a certain type (parameter_column)
# that exist at each location_id. This is the foundation for both analyses.
sensors_per_location_count = df_sensors.groupby(
    [parameter_column, "location_id"]
).size().reset_index(name='sensor_count_at_location')


# =====================================================================
# ANALYSIS 1: COVERAGE OF THE SENSORS (%TOTAL LOCATIONS)
# =====================================================================

# 1. Count how many locations have *at least one* sensor of each type.
# We just need to count the unique location_ids for each parameter_column.
sensors_count_total = sensors_per_location_count.groupby(parameter_column)['location_id'].count().reset_index(name='nb_locations')

# 2. Calculate Coverage %
total_locations = locations.shape[0]
sensors_count_total["coverage%"] = round(sensors_count_total["nb_locations"] / total_locations * 100, 2)
sensors_count_total = sensors_count_total.sort_values(by="nb_locations", ascending=False)

print(f"\n{'='*44}\n{'COVERAGE OF THE SENSORS (%TOTAL LOCATIONS)':^44}\n{'='*44}")
display(sensors_count_total)


# =====================================================================
# ANALYSIS 2: MULTIPLE SENSORS AT THE SAME LOCATION
# =====================================================================

# 1. Filter the core count table to only include rows where sensor_count_at_location > 1
multiple_sensors_df = sensors_per_location_count[
    sensors_per_location_count['sensor_count_at_location'] > 1
]

# 2. Now group this filtered table by the parameter to count how many locations
# have multiple sensors for that parameter.
# We use value_counts() on the sensor_count_at_location column to get the distribution.
sensors_count_with_multiple_sensors = multiple_sensors_df.groupby(parameter_column)['sensor_count_at_location'].value_counts().reset_index(name='nb_locations')
sensors_count_with_multiple_sensors.rename(columns={'sensor_count_at_location': 'count_per_location'}, inplace=True)
sensors_count_with_multiple_sensors = sensors_count_with_multiple_sensors.sort_values(by=[parameter_column, "nb_locations"], ascending=[True, False])


print(f"\n{'='*44}\n{'MULTIPLE SENSORS AT THE SAME LOCATION (Count Distribution)':^44}\n{'='*44}")
display(sensors_count_with_multiple_sensors)
# Out:
# ========================================
# SENSORS OVERVIEW
#
# Unique name: 18
# Unique location_id: 107
#
#
# ============================================
#  COVERAGE OF THE SENSORS (%TOTAL LOCATIONS)
# ============================================
#                    name  nb_locations  coverage%
# 10           pm25 µg/m³           105      98.13
# 7              o3 µg/m³            95      88.79
# 9            pm10 µg/m³            94      87.85
# 4             no2 µg/m³            87      81.31
# 1              co µg/m³            82      76.64
# 13            so2 µg/m³            73      68.22
# 3               no2 ppb            64      59.81
# 0                co ppb            63      58.88
# 5               nox ppb            63      58.88
# 2                no ppb            63      58.88
# 11   relativehumidity %            60      56.07
# 14        temperature c            60      56.07
# 12              so2 ppb            55      51.40
# 16   wind_direction deg            54      50.47
# 17       wind_speed m/s            54      50.47
# 8             pm1 µg/m³             6       5.61
# 15  um003 particles/cm³             6       5.61
# 6                o3 ppm             1       0.93
# ============================================
# MULTIPLE SENSORS AT THE SAME LOCATION (Count Distribution)
# ============================================
#          name  count_per_location  nb_locations
# 0    o3 µg/m³                   2            50
# 1  pm10 µg/m³                   2            53
# 2  pm25 µg/m³                   2            53

# %% [markdown]
# ### Measurements

# %%
location_id = 13
sensor_id = 13866

measurements = request_openaq(
    f"https://api.openaq.org/v3/sensors/{sensor_id}/measurements", {"limit": 1000,},
)

measurements["location_id"] = location_id
measurements["sensor_id"] = sensor_id

# %%
# Add sensor_id manually
print(measurements.shape)
measurements.head(1).to_dict(orient='records')
# Out:
# (1000, 26)
# [{'value': 11.3,
#   'coordinates': None,
#   'summary': None,
#   'flagInfo.hasFlags': False,
#   'parameter.id': 5,
#   'parameter.name': 'no2',
#   'parameter.units': 'µg/m³',
#   'parameter.displayName': None,
#   'period.label': 'raw',
#   'period.interval': '01:00:00',
#   'period.datetimeFrom.utc': '2016-11-02T17:30:00Z',
#   'period.datetimeFrom.local': '2016-11-02T23:00:00+05:30',
#   'period.datetimeTo.utc': '2016-11-02T18:30:00Z',
#   'period.datetimeTo.local': '2016-11-03T00:00:00+05:30',
#   'coverage.expectedCount': 1,
#   'coverage.expectedInterval': '01:00:00',
#   'coverage.observedCount': 1,
#   'coverage.observedInterval': '00:15:00',
#   'coverage.percentComplete': 100.0,
#   'coverage.percentCoverage': 0.0,
#   'coverage.datetimeFrom.utc': '2016-11-02T18:15:00Z',
#   'coverage.datetimeFrom.local': '2016-11-02T23:45:00+05:30',
#   'coverage.datetimeTo.utc': '2016-11-02T18:30:00Z',
#   'coverage.datetimeTo.local': '2016-11-03T00:00:00+05:30',
#   'location_id': 13,
#   'sensor_id': 13866}]

# %%
from datetime import datetime as dt

# Create new columns with proper datetime objects
df_measurements = measurements.copy()
df_measurements["datetimeFrom_utc"] = pd.to_datetime(df_measurements["period.datetimeFrom.utc"])
df_measurements["datetimeFrom_local"] = pd.to_datetime(df_measurements["period.datetimeFrom.local"])
df_measurements["datetimeTo_utc"] = pd.to_datetime(df_measurements["period.datetimeTo.utc"])
df_measurements["datetimeTo_local"] = pd.to_datetime(df_measurements["period.datetimeTo.local"])

# Filter measurements for a specific date (e.g., 2016-11-03)
date_mask = df_measurements["datetimeFrom_local"].dt.date == pd.to_datetime("2016-11-03").date()
ddf_measurements_filtered= df_measurements[date_mask][["location_id", "sensor_id", "parameter.id", "datetimeFrom_local", "datetimeTo_local", "period.interval", "value"]]
ddf_measurements_filtered

# df_measurements[date_mask]
# df_measurements["datetimeFrom_utc_str"] = df_measurements.dt.strftime('%Y-%m-%d %H:%M:%S')
# Out:
#     location_id  sensor_id  parameter.id        datetimeFrom_local          datetimeTo_local period.interval  value
# 1            13      13866             5 2016-11-03 16:15:00+05:30 2016-11-03 17:15:00+05:30        01:00:00    8.6
# 2            13      13866             5 2016-11-03 16:30:00+05:30 2016-11-03 17:30:00+05:30        01:00:00    8.6
# 3            13      13866             5 2016-11-03 16:45:00+05:30 2016-11-03 17:45:00+05:30        01:00:00    9.3
# 4            13      13866             5 2016-11-03 17:00:00+05:30 2016-11-03 18:00:00+05:30        01:00:00   10.6
# 5            13      13866             5 2016-11-03 17:15:00+05:30 2016-11-03 18:15:00+05:30        01:00:00    8.6
# 6            13      13866             5 2016-11-03 17:30:00+05:30 2016-11-03 18:30:00+05:30        01:00:00    8.0
# 7            13      13866             5 2016-11-03 17:45:00+05:30 2016-11-03 18:45:00+05:30        01:00:00    8.5
# 8            13      13866             5 2016-11-03 18:00:00+05:30 2016-11-03 19:00:00+05:30        01:00:00    8.7
# 9            13      13866             5 2016-11-03 18:15:00+05:30 2016-11-03 19:15:00+05:30        01:00:00    7.5
# 10           13      13866             5 2016-11-03 18:30:00+05:30 2016-11-03 19:30:00+05:30        01:00:00    5.7
# 11           13      13866             5 2016-11-03 18:45:00+05:30 2016-11-03 19:45:00+05:30        01:00:00    6.2
# 12           13      13866             5 2016-11-03 19:00:00+05:30 2016-11-03 20:00:00+05:30        01:00:00    7.8
# 13           13      13866             5 2016-11-03 19:15:00+05:30 2016-11-03 20:15:00+05:30        01:00:00    8.6
# 14           13      13866             5 2016-11-03 19:30:00+05:30 2016-11-03 20:30:00+05:30        01:00:00    9.0
# 15           13      13866             5 2016-11-03 19:45:00+05:30 2016-11-03 20:45:00+05:30        01:00:00    8.8
# 16           13      13866             5 2016-11-03 20:00:00+05:30 2016-11-03 21:00:00+05:30        01:00:00    9.4
# 17           13      13866             5 2016-11-03 20:15:00+05:30 2016-11-03 21:15:00+05:30        01:00:00   10.2
# 18           13      13866             5 2016-11-03 20:30:00+05:30 2016-11-03 21:30:00+05:30        01:00:00    8.1
# 19           13      13866             5 2016-11-03 20:45:00+05:30 2016-11-03 21:45:00+05:30        01:00:00    9.7
# 20           13      13866             5 2016-11-03 21:00:00+05:30 2016-11-03 22:00:00+05:30        01:00:00   10.2
# 21           13      13866             5 2016-11-03 21:15:00+05:30 2016-11-03 22:15:00+05:30        01:00:00    9.7
# 22           13      13866             5 2016-11-03 21:30:00+05:30 2016-11-03 22:30:00+05:30        01:00:00    8.4
# 23           13      13866             5 2016-11-03 21:45:00+05:30 2016-11-03 22:45:00+05:30        01:00:00    8.6
# 24           13      13866             5 2016-11-03 22:00:00+05:30 2016-11-03 23:00:00+05:30        01:00:00    9.0
# 25           13      13866             5 2016-11-03 22:15:00+05:30 2016-11-03 23:15:00+05:30        01:00:00    8.0
# 26           13      13866             5 2016-11-03 22:30:00+05:30 2016-11-03 23:30:00+05:30        01:00:00    8.1
# 27           13      13866             5 2016-11-03 22:45:00+05:30 2016-11-03 23:45:00+05:30        01:00:00   11.3
# 28           13      13866             5 2016-11-03 23:15:00+05:30 2016-11-04 00:15:00+05:30        01:00:00    9.2
# 29           13      13866             5 2016-11-03 23:30:00+05:30 2016-11-04 00:30:00+05:30        01:00:00    8.6
# 30           13      13866             5 2016-11-03 23:45:00+05:30 2016-11-04 00:45:00+05:30        01:00:00    5.6

# %% [markdown]
# ### Hourly Measurements

# %%
location_id = 235
sensor_id = 12235609

res = request_openaq(
    f"https://api.openaq.org/v3/sensors/{sensor_id}/measurements/hourly",
    {
        "datetime_from": "2025-06-01T00:00:00+00:00",
        "datetime_to": "2025-06-02T00:00:00+00:00",
        "limit": 100,
        "pages": 1,
    },
)
res["meta"]

# hourly_measurements = res["results"]
# hourly_measurements["sensor_id"] = sensor_id
# hourly_measurements["location_id"] = location_id
# Out:
# {'name': 'openaq-api', 'website': '/', 'page': 1, 'limit': 100, 'found': 24}

# %%
res["results"]["parameter.name"].value_counts()
# Out:
# parameter.name
# pm10    24
# Name: count, dtype: int64

# %%
res["meta"]
# Out:
# {'name': 'openaq-api', 'website': '/', 'page': 1, 'limit': 1000, 'found': 0}

# %%
res["results"]
# Out:
# Empty DataFrame
# Columns: [sensor_id, location_id]
# Index: []

# %%
print(hourly_measurements.shape)
hourly_measurements.head(1)#.to_dict(orient='records')
# Out:
# (1000, 34)
#    value coordinates  flagInfo.hasFlags  parameter.id parameter.name parameter.units parameter.displayName period.label period.interval period.datetimeFrom.utc  period.datetimeFrom.local period.datetimeTo.utc    period.datetimeTo.local  summary.min  summary.q02  summary.q25  summary.median  summary.q75  summary.q98  summary.max  summary.avg  summary.sd  coverage.expectedCount coverage.expectedInterval  coverage.observedCount coverage.observedInterval  coverage.percentComplete  coverage.percentCoverage coverage.datetimeFrom.utc coverage.datetimeFrom.local coverage.datetimeTo.utc  coverage.datetimeTo.local  sensor_id  location_id
# 0  266.0        None              False             1           pm10           µg/m³                  None       1 hour        01:00:00    2025-02-18T21:30:00Z  2025-02-19T03:00:00+05:30  2025-02-18T22:30:00Z  2025-02-19T04:00:00+05:30        260.0       260.24        263.0           266.0        269.0       271.76        272.0        266.0    8.485281                       4                  01:00:00                       2                  00:30:00                      50.0                      50.0      2025-02-18T22:00:00Z   2025-02-19T03:30:00+05:30    2025-02-18T22:30:00Z  2025-02-19T04:00:00+05:30   12235609          235

# %%
hourly_measurements.iloc[-1]
# Out:
# value                                               23.1
# coordinates                                         None
# flagInfo.hasFlags                                  False
# parameter.id                                           5
# parameter.name                                       no2
# parameter.units                                    µg/m³
# parameter.displayName                               None
# period.label                                      1 hour
# period.interval                                 01:00:00
# period.datetimeFrom.utc             2017-02-21T20:30:00Z
# period.datetimeFrom.local      2017-02-22T02:00:00+05:30
# period.datetimeTo.utc               2017-02-21T21:30:00Z
# period.datetimeTo.local        2017-02-22T03:00:00+05:30
# summary.min                                         22.2
# summary.q02                                       22.234
# summary.q25                                       22.625
# summary.median                                     23.05
# summary.q75                                       23.475
# summary.q98                                       23.866
# summary.max                                         23.9
# summary.avg                                        23.05
# summary.sd                                      1.202082
# coverage.expectedCount                                 1
# coverage.expectedInterval                       00:15:00
# coverage.observedCount                                 2
# coverage.observedInterval                       00:30:00
# coverage.percentComplete                           200.0
# coverage.percentCoverage                            50.0
# coverage.datetimeFrom.utc           2017-02-21T20:00:00Z
# coverage.datetimeFrom.local    2017-02-22T01:30:00+05:30
# coverage.datetimeTo.utc             2017-02-21T21:30:00Z
# coverage.datetimeTo.local      2017-02-22T03:00:00+05:30
# sensor_id                                          13866
# location_id                                           13
# Name: 999, dtype: object

# %%
from datetime import datetime as dt
# DOCUMENTATION
# For a given timestamp (local), the 'hourly' measurements represent the average value
# over the PREVIOUS hour interval (datetimeFrom minus period.interval=1h) excluding the previous hour itself.
# E.g., for datetimeFrom.local = '2016-11-03 01:00:00' and period.interval = '1h',
# the measurement value corresponds to the average of the values between '2016-11-03 00:00:01' and '2016-11-03 01:00:00'.

# Create new columns with proper datetime objects
df_hourly_measurements = hourly_measurements.copy()
df_hourly_measurements["datetimeFrom_utc"] = pd.to_datetime(df_hourly_measurements["period.datetimeFrom.utc"])
df_hourly_measurements["datetimeFrom_local"] = pd.to_datetime(df_hourly_measurements["period.datetimeFrom.local"])
df_hourly_measurements["datetimeTo_utc"] = pd.to_datetime(df_hourly_measurements["period.datetimeTo.utc"])
df_hourly_measurements["datetimeTo_local"] = pd.to_datetime(df_hourly_measurements["period.datetimeTo.local"])

# Filter measurements for a specific date (e.g., 2016-11-03)
date_mask = df_hourly_measurements["datetimeFrom_local"].dt.date == pd.to_datetime("2016-11-04").date()
ddf_hourly_measurements_filtered= df_hourly_measurements[date_mask][["location_id", "sensor_id", "parameter.id", "datetimeFrom_local", "datetimeTo_local", "period.interval", "value"]]
ddf_hourly_measurements_filtered

# df_measurements[date_mask]
# df_measurements["datetimeFrom_utc_str"] = df_measurements.dt.strftime('%Y-%m-%d %H:%M:%S')
# Out:
#     location_id  sensor_id  parameter.id        datetimeFrom_local          datetimeTo_local period.interval  value
# 8            13      13866             5 2016-11-04 00:00:00+05:30 2016-11-04 01:00:00+05:30        01:00:00   7.15
# 9            13      13866             5 2016-11-04 01:00:00+05:30 2016-11-04 02:00:00+05:30        01:00:00   2.50
# 10           13      13866             5 2016-11-04 02:00:00+05:30 2016-11-04 03:00:00+05:30        01:00:00   8.40
# 11           13      13866             5 2016-11-04 03:00:00+05:30 2016-11-04 04:00:00+05:30        01:00:00  10.90
# 12           13      13866             5 2016-11-04 04:00:00+05:30 2016-11-04 05:00:00+05:30        01:00:00  11.30
# 13           13      13866             5 2016-11-04 05:00:00+05:30 2016-11-04 06:00:00+05:30        01:00:00  10.50
# 14           13      13866             5 2016-11-04 06:00:00+05:30 2016-11-04 07:00:00+05:30        01:00:00  10.10
# 15           13      13866             5 2016-11-04 07:00:00+05:30 2016-11-04 08:00:00+05:30        01:00:00   8.40
# 16           13      13866             5 2016-11-04 08:00:00+05:30 2016-11-04 09:00:00+05:30        01:00:00   9.38
# 17           13      13866             5 2016-11-04 09:00:00+05:30 2016-11-04 10:00:00+05:30        01:00:00   8.55
# 18           13      13866             5 2016-11-04 10:00:00+05:30 2016-11-04 11:00:00+05:30        01:00:00   7.65
# 19           13      13866             5 2016-11-04 11:00:00+05:30 2016-11-04 12:00:00+05:30        01:00:00   2.35
# 20           13      13866             5 2016-11-04 12:00:00+05:30 2016-11-04 13:00:00+05:30        01:00:00   2.10
# 21           13      13866             5 2016-11-04 15:00:00+05:30 2016-11-04 16:00:00+05:30        01:00:00   2.00
# 22           13      13866             5 2016-11-04 16:00:00+05:30 2016-11-04 17:00:00+05:30        01:00:00   1.60
# 23           13      13866             5 2016-11-04 23:00:00+05:30 2016-11-05 00:00:00+05:30        01:00:00  84.50

# %% [markdown]
# ### Instruments

# %%
id = 2

instruments = request_openaq(
    "https://api.openaq.org/v3/instruments/2", {"limit": 1000,},
)

# %%
instruments
# Out:
#    id                name  isMonitor  manufacturer.id                  manufacturer.name
# 0   2  Government Monitor       True                4  Unknown Governmental Organization

# %% [markdown]
# ### Download archives from AWS

# %%
import boto3
import os
import gzip

from botocore import UNSIGNED
from botocore.config import Config


def get_location_archives_aws(location_id: int,year: int, month: int | None = None, **kwargs) -> list[str]:
    """Download all archives CSV files from OpenAQ S3 bucket and unzip them locally."""

    debug = kwargs.get("debug", False)
    trace_prefix = kwargs.get("trace_prefix", "")

    # Configuration (OpenAQ)
    s3_prefix_month = f"/month={month:02d}" if month is not None else ""
    BUCKET_NAME = "openaq-data-archive"
    S3_PREFIX = f"records/csv.gz/locationid={location_id}/year={year}{s3_prefix_month}"
    LOCAL_GZ_DIR = os.path.join(config.DATA_PATH, "tmp")
    LOCAL_CSV_DIR = os.path.join(config.DATA_PATH, "aws")

    s3 = boto3.client(
        "s3", region_name="us-east-1", config=Config(signature_version=UNSIGNED)
    )

    # ---------------------------------------------------------------------
    # LIST ALL FILES UNDER THE S3 PREFIX

    logger.debug(f"Scanning s3://{BUCKET_NAME}/{S3_PREFIX}")

    paginator = s3.get_paginator("list_objects_v2")
    pages = paginator.paginate(Bucket=BUCKET_NAME, Prefix=S3_PREFIX)

    download_list = []

    # We loop through pages just to collect the keys first
    for page in pages:
        if "Contents" in page:
            for obj in page["Contents"]:
                key = obj["Key"]
                if not key.endswith("/"):  # ignore folders (ending with /)
                    download_list.append(key)

    total_files = len(download_list)
    if total_files > 0:
        logger.info(f"Found {total_files} files. Starting downloads...")
    else:
        logger.warning(f"No files found for s3://{BUCKET_NAME}/{S3_PREFIX}. Exiting.")
        return []

    # pprint(download_list)

    # ---------------------------------------------------------------------
    # DOWNLOAD ALL FILES AND UNZIP

    # Create directories if they don't exist
    os.makedirs(LOCAL_GZ_DIR, exist_ok=True)
    os.makedirs(LOCAL_CSV_DIR, exist_ok=True)

    # for s3_key in tqdm(download_list, unit='file', desc="Downloading files"):
    errors_s3_keys = []
    csv_file_paths = []
    for index, s3_key in enumerate(download_list):
        if debug:
            logger.trace(f"{trace_prefix}Downloading {index + 1}/{total_files}: {s3_key}")

        # Create paths: local_file_path and temp_gz_path
        relative_path = s3_key[len(S3_PREFIX) :].lstrip(os.path.sep)
        relative_path = relative_path.split(
            os.path.sep
        )[
            -1
        ]  # cleanup to filename only (will erase files with same name in different subdirs)
        gz_file_path = os.path.join(LOCAL_GZ_DIR, relative_path)
        csv_file_path = os.path.join(LOCAL_CSV_DIR, relative_path)[
            :-3
        ]  # remove .gz extension
        # logger.trace(f"gz_file_path: {gz_file_path}")
        # logger.trace(f"csv_file_path: {csv_file_path}")

        # 3. Download
        try:
            # Download to tmp/*.gz
            s3.download_file(BUCKET_NAME, s3_key, gz_file_path)

            # Unzip to csv/*.csv
            with gzip.open(gz_file_path, "rb") as f_in:
                with open(csv_file_path, "wb") as f_out:
                    f_out.write(f_in.read())
            os.remove(gz_file_path)

            # Add the final path to the list
            csv_file_paths.append(csv_file_path)

        except Exception as e:  # don't break loop on single file error
            errors_s3_keys.append(s3_key)
            logger.error(f"Error downloading {s3_key}: {e}")

    os.rmdir(LOCAL_GZ_DIR)

    logger.success(f"Finished downloading {total_files} files.")

    if len(errors_s3_keys) > 0:
        logger.warning(f"{len(errors_s3_keys)} errors during download:")
        for error_key in errors_s3_keys:
            logger.warning(f" - {error_key}")

    return csv_file_paths

# %%
csv_files = get_location_archives_aws(location_id=13, year=2016, month=12)
# Out:
# 09:40:38    DEBUG |  Scanning s3://openaq-data-archive/records/csv.gz/locationid=13/year=2016/month=12
# 09:40:39     INFO |  Found 23 files. Starting downloads...
# 09:40:45  SUCCESS |  Finished downloading 23 files.

# %%
df[["parameter", "units"]].value_counts()
# Out:
# parameter  units
# pm25       µg/m³    675
# no2        µg/m³    553
# Name: count, dtype: int64

# %%
# display(locations.head(1).to_dict(orient='records'))

# %% [markdown]
# #### Test

# %% [markdown]
# # RETRY FROM location_id= 5627

# %%
MANUAL_LOCATION_IDS = [
    # 13,
    # 15,
    # 16,
    # 17,
    # 50,
    # 103,
    # 235,
    # 236,
    # 301,
    # 431,
    # 2503,
    # 2587,
    # 2597,
    # 5404,
    # 5509,
    # 5540,
    # 5541,
    # 5570,
    # 5581,
    # 5586,
    # 5588,
    # 5598,
    # 5610,
    # 5613,
    # 5616,
    # 5617,
    # 5622,
    # 5626,
    # 5627,
    # 5630,
    5634,
    5639,
    5641,
    5650,
    5665,
    5742,
    5743,
    5744,
    5753,
    5754,
    5755,
    5759,
    5760,
    5761,
    5762,
    5763,
    5765,
    5766,
    6314,
    6356,
    6357,
    6358,
    6359,
    6924,
    6929,
    6931,
    6932,
    6934,
    6936,
    6938,
    6949,
    6953,
    6957,
    6960,
    6972,
    6978,
    6980,
    6986,
    6988,
    7005,
    7044,
    7434,
    8092,
    8118,
    8235,
    8239,
    8319,
    8365,
    8472,
    8475,
    8915,
    8917,
    10484,
    10485,
    10486,
    10487,
    10488,
    10489,
    10820,
    10825,
    10831,
    10900,
    10908,
    10919,
    10920,
    10921,
    11603,
    11607,
    2860223,
    3024966,
    3409519,
    3410004,
    4663956,
    6105800,
    6119272,
    6125489,
    6145551,
]

# %%
# newdelhi_location_ids = locations["id"].to_list()
# newdelhi_location_ids
# # newdelhi_location_ids = [13, 15]

location_processed = 0
number_of_locations = len(MANUAL_LOCATION_IDS)
for location_id in MANUAL_LOCATION_IDS:
    csv_files = get_location_archives_aws(location_id=location_id, year=2025, debug=True, trace_prefix=f"[{location_processed + 1}/{number_of_locations}] ")
    location_processed += 1
# Out:
# 10:05:15    DEBUG |  Scanning s3://openaq-data-archive/records/csv.gz/locationid=5627/year=2025
# 10:05:16     INFO |  Found 287 files. Starting downloads...
# 10:05:16    TRACE |   󰘍 [1/79] Downloading 1/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250219.csv.gz
# 10:05:16    TRACE |   󰘍 [1/79] Downloading 2/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250220.csv.gz
# 10:05:16    TRACE |   󰘍 [1/79] Downloading 3/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250221.csv.gz
# 10:05:16    TRACE |   󰘍 [1/79] Downloading 4/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250222.csv.gz
# 10:05:17    TRACE |   󰘍 [1/79] Downloading 5/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250223.csv.gz
# 10:05:17    TRACE |   󰘍 [1/79] Downloading 6/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250224.csv.gz
# 10:05:17    TRACE |   󰘍 [1/79] Downloading 7/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250225.csv.gz
# 10:05:17    TRACE |   󰘍 [1/79] Downloading 8/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250226.csv.gz
# 10:05:18    TRACE |   󰘍 [1/79] Downloading 9/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250227.csv.gz
# 10:05:18    TRACE |   󰘍 [1/79] Downloading 10/287: records/csv.gz/locationid=5627/year=2025/month=02/location-5627-20250228.csv.gz
# 10:05:18    TRACE |   󰘍 [1/79] Downloading 11/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250301.csv.gz
# 10:05:18    TRACE |   󰘍 [1/79] Downloading 12/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250302.csv.gz
# 10:05:19    TRACE |   󰘍 [1/79] Downloading 13/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250303.csv.gz
# 10:05:19    TRACE |   󰘍 [1/79] Downloading 14/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250304.csv.gz
# 10:05:19    TRACE |   󰘍 [1/79] Downloading 15/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250305.csv.gz
# 10:05:19    TRACE |   󰘍 [1/79] Downloading 16/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250306.csv.gz
# 10:05:20    TRACE |   󰘍 [1/79] Downloading 17/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250307.csv.gz
# 10:05:20    TRACE |   󰘍 [1/79] Downloading 18/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250308.csv.gz
# 10:05:19    TRACE |   󰘍 [1/79] Downloading 19/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250310.csv.gz
# 10:05:19    TRACE |   󰘍 [1/79] Downloading 20/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250311.csv.gz
# 10:05:19    TRACE |   󰘍 [1/79] Downloading 21/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250312.csv.gz
# 10:05:20    TRACE |   󰘍 [1/79] Downloading 22/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250313.csv.gz
# 10:05:20    TRACE |   󰘍 [1/79] Downloading 23/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250314.csv.gz
# 10:05:20    TRACE |   󰘍 [1/79] Downloading 24/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250315.csv.gz
# 10:05:21    TRACE |   󰘍 [1/79] Downloading 25/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250316.csv.gz
# 10:05:21    TRACE |   󰘍 [1/79] Downloading 26/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250317.csv.gz
# 10:05:21    TRACE |   󰘍 [1/79] Downloading 27/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250318.csv.gz
# 10:05:21    TRACE |   󰘍 [1/79] Downloading 28/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250319.csv.gz
# 10:05:22    TRACE |   󰘍 [1/79] Downloading 29/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250320.csv.gz
# 10:05:22    TRACE |   󰘍 [1/79] Downloading 30/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250321.csv.gz
# 10:05:22    TRACE |   󰘍 [1/79] Downloading 31/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250322.csv.gz
# 10:05:22    TRACE |   󰘍 [1/79] Downloading 32/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250323.csv.gz
# 10:05:23    TRACE |   󰘍 [1/79] Downloading 33/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250324.csv.gz
# 10:05:23    TRACE |   󰘍 [1/79] Downloading 34/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250325.csv.gz
# 10:05:23    TRACE |   󰘍 [1/79] Downloading 35/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250326.csv.gz
# 10:05:23    TRACE |   󰘍 [1/79] Downloading 36/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250327.csv.gz
# 10:05:24    TRACE |   󰘍 [1/79] Downloading 37/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250328.csv.gz
# 10:05:24    TRACE |   󰘍 [1/79] Downloading 38/287: records/csv.gz/locationid=5627/year=2025/month=03/location-5627-20250331.csv.gz
# 10:05:24    TRACE |   󰘍 [1/79] Downloading 39/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250402.csv.gz
# 10:05:24    TRACE |   󰘍 [1/79] Downloading 40/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250403.csv.gz
# 10:05:25    TRACE |   󰘍 [1/79] Downloading 41/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250404.csv.gz
# 10:05:25    TRACE |   󰘍 [1/79] Downloading 42/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250405.csv.gz
# 10:05:25    TRACE |   󰘍 [1/79] Downloading 43/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250406.csv.gz
# 10:05:25    TRACE |   󰘍 [1/79] Downloading 44/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250407.csv.gz
# 10:05:26    TRACE |   󰘍 [1/79] Downloading 45/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250408.csv.gz
# 10:05:26    TRACE |   󰘍 [1/79] Downloading 46/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250409.csv.gz
# 10:05:26    TRACE |   󰘍 [1/79] Downloading 47/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250411.csv.gz
# 10:05:26    TRACE |   󰘍 [1/79] Downloading 48/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250412.csv.gz
# 10:05:27    TRACE |   󰘍 [1/79] Downloading 49/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250413.csv.gz
# 10:05:27    TRACE |   󰘍 [1/79] Downloading 50/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250414.csv.gz
# 10:05:27    TRACE |   󰘍 [1/79] Downloading 51/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250415.csv.gz
# 10:05:28    TRACE |   󰘍 [1/79] Downloading 52/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250416.csv.gz
# 10:05:28    TRACE |   󰘍 [1/79] Downloading 53/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250417.csv.gz
# 10:05:28    TRACE |   󰘍 [1/79] Downloading 54/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250418.csv.gz
# 10:05:28    TRACE |   󰘍 [1/79] Downloading 55/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250419.csv.gz
# 10:05:29    TRACE |   󰘍 [1/79] Downloading 56/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250420.csv.gz
# 10:05:29    TRACE |   󰘍 [1/79] Downloading 57/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250421.csv.gz
# 10:05:29    TRACE |   󰘍 [1/79] Downloading 58/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250422.csv.gz
# 10:05:29    TRACE |   󰘍 [1/79] Downloading 59/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250423.csv.gz
# 10:05:30    TRACE |   󰘍 [1/79] Downloading 60/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250424.csv.gz
# 10:05:30    TRACE |   󰘍 [1/79] Downloading 61/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250425.csv.gz
# 10:05:30    TRACE |   󰘍 [1/79] Downloading 62/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250426.csv.gz
# 10:05:31    TRACE |   󰘍 [1/79] Downloading 63/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250427.csv.gz
# 10:05:31    TRACE |   󰘍 [1/79] Downloading 64/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250428.csv.gz
# 10:05:31    TRACE |   󰘍 [1/79] Downloading 65/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250429.csv.gz
# 10:05:31    TRACE |   󰘍 [1/79] Downloading 66/287: records/csv.gz/locationid=5627/year=2025/month=04/location-5627-20250430.csv.gz
# 10:05:32    TRACE |   󰘍 [1/79] Downloading 67/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250501.csv.gz
# 10:05:32    TRACE |   󰘍 [1/79] Downloading 68/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250502.csv.gz
# 10:05:32    TRACE |   󰘍 [1/79] Downloading 69/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250503.csv.gz
# 10:05:32    TRACE |   󰘍 [1/79] Downloading 70/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250504.csv.gz
# 10:05:33    TRACE |   󰘍 [1/79] Downloading 71/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250505.csv.gz
# 10:05:33    TRACE |   󰘍 [1/79] Downloading 72/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250506.csv.gz
# 10:05:33    TRACE |   󰘍 [1/79] Downloading 73/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250507.csv.gz
# 10:05:33    TRACE |   󰘍 [1/79] Downloading 74/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250508.csv.gz
# 10:05:34    TRACE |   󰘍 [1/79] Downloading 75/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250509.csv.gz
# 10:05:34    TRACE |   󰘍 [1/79] Downloading 76/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250510.csv.gz
# 10:05:34    TRACE |   󰘍 [1/79] Downloading 77/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250511.csv.gz
# 10:05:35    TRACE |   󰘍 [1/79] Downloading 78/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250512.csv.gz
# 10:05:35    TRACE |   󰘍 [1/79] Downloading 79/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250513.csv.gz
# 10:05:35    TRACE |   󰘍 [1/79] Downloading 80/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250514.csv.gz
# 10:05:35    TRACE |   󰘍 [1/79] Downloading 81/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250515.csv.gz
# 10:05:36    TRACE |   󰘍 [1/79] Downloading 82/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250516.csv.gz
# 10:05:36    TRACE |   󰘍 [1/79] Downloading 83/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250517.csv.gz
# 10:05:36    TRACE |   󰘍 [1/79] Downloading 84/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250518.csv.gz
# 10:05:36    TRACE |   󰘍 [1/79] Downloading 85/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250519.csv.gz
# 10:05:37    TRACE |   󰘍 [1/79] Downloading 86/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250520.csv.gz
# 10:05:37    TRACE |   󰘍 [1/79] Downloading 87/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250521.csv.gz
# 10:05:37    TRACE |   󰘍 [1/79] Downloading 88/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250522.csv.gz
# 10:05:37    TRACE |   󰘍 [1/79] Downloading 89/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250523.csv.gz
# 10:05:38    TRACE |   󰘍 [1/79] Downloading 90/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250524.csv.gz
# 10:05:38    TRACE |   󰘍 [1/79] Downloading 91/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250525.csv.gz
# 10:05:38    TRACE |   󰘍 [1/79] Downloading 92/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250526.csv.gz
# 10:05:39    TRACE |   󰘍 [1/79] Downloading 93/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250527.csv.gz
# 10:05:39    TRACE |   󰘍 [1/79] Downloading 94/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250528.csv.gz
# 10:05:39    TRACE |   󰘍 [1/79] Downloading 95/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250529.csv.gz
# 10:05:39    TRACE |   󰘍 [1/79] Downloading 96/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250530.csv.gz
# 10:05:40    TRACE |   󰘍 [1/79] Downloading 97/287: records/csv.gz/locationid=5627/year=2025/month=05/location-5627-20250531.csv.gz
# 10:05:40    TRACE |   󰘍 [1/79] Downloading 98/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250601.csv.gz
# 10:05:40    TRACE |   󰘍 [1/79] Downloading 99/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250602.csv.gz
# 10:05:40    TRACE |   󰘍 [1/79] Downloading 100/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250603.csv.gz
# 10:05:41    TRACE |   󰘍 [1/79] Downloading 101/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250604.csv.gz
# 10:05:41    TRACE |   󰘍 [1/79] Downloading 102/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250605.csv.gz
# 10:05:41    TRACE |   󰘍 [1/79] Downloading 103/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250606.csv.gz
# 10:05:42    TRACE |   󰘍 [1/79] Downloading 104/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250607.csv.gz
# 10:05:42    TRACE |   󰘍 [1/79] Downloading 105/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250608.csv.gz
# 10:05:42    TRACE |   󰘍 [1/79] Downloading 106/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250609.csv.gz
# 10:05:42    TRACE |   󰘍 [1/79] Downloading 107/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250610.csv.gz
# 10:05:43    TRACE |   󰘍 [1/79] Downloading 108/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250611.csv.gz
# 10:05:43    TRACE |   󰘍 [1/79] Downloading 109/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250612.csv.gz
# 10:05:43    TRACE |   󰘍 [1/79] Downloading 110/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250613.csv.gz
# 10:05:43    TRACE |   󰘍 [1/79] Downloading 111/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250614.csv.gz
# 10:05:44    TRACE |   󰘍 [1/79] Downloading 112/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250615.csv.gz
# 10:05:44    TRACE |   󰘍 [1/79] Downloading 113/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250616.csv.gz
# 10:05:44    TRACE |   󰘍 [1/79] Downloading 114/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250617.csv.gz
# 10:05:44    TRACE |   󰘍 [1/79] Downloading 115/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250618.csv.gz
# 10:05:45    TRACE |   󰘍 [1/79] Downloading 116/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250619.csv.gz
# 10:05:45    TRACE |   󰘍 [1/79] Downloading 117/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250620.csv.gz
# 10:05:45    TRACE |   󰘍 [1/79] Downloading 118/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250621.csv.gz
# 10:05:45    TRACE |   󰘍 [1/79] Downloading 119/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250622.csv.gz
# 10:05:46    TRACE |   󰘍 [1/79] Downloading 120/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250623.csv.gz
# 10:05:46    TRACE |   󰘍 [1/79] Downloading 121/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250624.csv.gz
# 10:05:46    TRACE |   󰘍 [1/79] Downloading 122/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250625.csv.gz
# 10:05:47    TRACE |   󰘍 [1/79] Downloading 123/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250626.csv.gz
# 10:05:47    TRACE |   󰘍 [1/79] Downloading 124/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250627.csv.gz
# 10:05:47    TRACE |   󰘍 [1/79] Downloading 125/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250628.csv.gz
# 10:05:47    TRACE |   󰘍 [1/79] Downloading 126/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250629.csv.gz
# 10:05:47    TRACE |   󰘍 [1/79] Downloading 127/287: records/csv.gz/locationid=5627/year=2025/month=06/location-5627-20250630.csv.gz
# 10:05:48    TRACE |   󰘍 [1/79] Downloading 128/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250701.csv.gz
# 10:05:48    TRACE |   󰘍 [1/79] Downloading 129/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250702.csv.gz
# 10:05:48    TRACE |   󰘍 [1/79] Downloading 130/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250703.csv.gz
# 10:05:49    TRACE |   󰘍 [1/79] Downloading 131/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250704.csv.gz
# 10:05:49    TRACE |   󰘍 [1/79] Downloading 132/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250705.csv.gz
# 10:05:49    TRACE |   󰘍 [1/79] Downloading 133/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250706.csv.gz
# 10:05:49    TRACE |   󰘍 [1/79] Downloading 134/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250707.csv.gz
# 10:05:50    TRACE |   󰘍 [1/79] Downloading 135/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250708.csv.gz
# 10:05:50    TRACE |   󰘍 [1/79] Downloading 136/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250709.csv.gz
# 10:05:50    TRACE |   󰘍 [1/79] Downloading 137/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250710.csv.gz
# 10:05:50    TRACE |   󰘍 [1/79] Downloading 138/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250711.csv.gz
# 10:05:51    TRACE |   󰘍 [1/79] Downloading 139/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250712.csv.gz
# 10:05:51    TRACE |   󰘍 [1/79] Downloading 140/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250713.csv.gz
# 10:05:50    TRACE |   󰘍 [1/79] Downloading 141/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250714.csv.gz
# 10:05:50    TRACE |   󰘍 [1/79] Downloading 142/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250715.csv.gz
# 10:05:50    TRACE |   󰘍 [1/79] Downloading 143/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250716.csv.gz
# 10:05:51    TRACE |   󰘍 [1/79] Downloading 144/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250717.csv.gz
# 10:05:51    TRACE |   󰘍 [1/79] Downloading 145/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250718.csv.gz
# 10:05:51    TRACE |   󰘍 [1/79] Downloading 146/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250719.csv.gz
# 10:05:51    TRACE |   󰘍 [1/79] Downloading 147/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250720.csv.gz
# 10:05:52    TRACE |   󰘍 [1/79] Downloading 148/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250721.csv.gz
# 10:05:52    TRACE |   󰘍 [1/79] Downloading 149/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250722.csv.gz
# 10:05:52    TRACE |   󰘍 [1/79] Downloading 150/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250723.csv.gz
# 10:05:53    TRACE |   󰘍 [1/79] Downloading 151/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250724.csv.gz
# 10:05:53    TRACE |   󰘍 [1/79] Downloading 152/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250725.csv.gz
# 10:05:53    TRACE |   󰘍 [1/79] Downloading 153/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250726.csv.gz
# 10:05:53    TRACE |   󰘍 [1/79] Downloading 154/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250727.csv.gz
# 10:05:54    TRACE |   󰘍 [1/79] Downloading 155/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250728.csv.gz
# 10:05:54    TRACE |   󰘍 [1/79] Downloading 156/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250729.csv.gz
# 10:05:54    TRACE |   󰘍 [1/79] Downloading 157/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250730.csv.gz
# 10:05:54    TRACE |   󰘍 [1/79] Downloading 158/287: records/csv.gz/locationid=5627/year=2025/month=07/location-5627-20250731.csv.gz
# 10:05:55    TRACE |   󰘍 [1/79] Downloading 159/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250801.csv.gz
# 10:05:55    TRACE |   󰘍 [1/79] Downloading 160/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250802.csv.gz
# 10:05:55    TRACE |   󰘍 [1/79] Downloading 161/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250803.csv.gz
# 10:05:55    TRACE |   󰘍 [1/79] Downloading 162/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250804.csv.gz
# 10:05:56    TRACE |   󰘍 [1/79] Downloading 163/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250805.csv.gz
# 10:05:56    TRACE |   󰘍 [1/79] Downloading 164/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250806.csv.gz
# 10:05:56    TRACE |   󰘍 [1/79] Downloading 165/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250807.csv.gz
# 10:05:56    TRACE |   󰘍 [1/79] Downloading 166/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250808.csv.gz
# 10:05:57    TRACE |   󰘍 [1/79] Downloading 167/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250809.csv.gz
# 10:05:57    TRACE |   󰘍 [1/79] Downloading 168/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250810.csv.gz
# 10:05:57    TRACE |   󰘍 [1/79] Downloading 169/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250811.csv.gz
# 10:05:57    TRACE |   󰘍 [1/79] Downloading 170/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250812.csv.gz
# 10:05:58    TRACE |   󰘍 [1/79] Downloading 171/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250813.csv.gz
# 10:05:58    TRACE |   󰘍 [1/79] Downloading 172/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250814.csv.gz
# 10:05:58    TRACE |   󰘍 [1/79] Downloading 173/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250815.csv.gz
# 10:05:58    TRACE |   󰘍 [1/79] Downloading 174/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250816.csv.gz
# 10:05:59    TRACE |   󰘍 [1/79] Downloading 175/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250817.csv.gz
# 10:05:59    TRACE |   󰘍 [1/79] Downloading 176/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250818.csv.gz
# 10:05:59    TRACE |   󰘍 [1/79] Downloading 177/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250819.csv.gz
# 10:05:59    TRACE |   󰘍 [1/79] Downloading 178/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250820.csv.gz
# 10:06:00    TRACE |   󰘍 [1/79] Downloading 179/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250821.csv.gz
# 10:06:00    TRACE |   󰘍 [1/79] Downloading 180/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250822.csv.gz
# 10:06:00    TRACE |   󰘍 [1/79] Downloading 181/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250823.csv.gz
# 10:06:00    TRACE |   󰘍 [1/79] Downloading 182/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250824.csv.gz
# 10:06:01    TRACE |   󰘍 [1/79] Downloading 183/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250825.csv.gz
# 10:06:01    TRACE |   󰘍 [1/79] Downloading 184/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250826.csv.gz
# 10:06:01    TRACE |   󰘍 [1/79] Downloading 185/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250827.csv.gz
# 10:06:01    TRACE |   󰘍 [1/79] Downloading 186/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250828.csv.gz
# 10:06:02    TRACE |   󰘍 [1/79] Downloading 187/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250829.csv.gz
# 10:06:02    TRACE |   󰘍 [1/79] Downloading 188/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250830.csv.gz
# 10:06:02    TRACE |   󰘍 [1/79] Downloading 189/287: records/csv.gz/locationid=5627/year=2025/month=08/location-5627-20250831.csv.gz
# 10:06:02    TRACE |   󰘍 [1/79] Downloading 190/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250901.csv.gz
# 10:06:03    TRACE |   󰘍 [1/79] Downloading 191/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250902.csv.gz
# 10:06:03    TRACE |   󰘍 [1/79] Downloading 192/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250903.csv.gz
# 10:06:03    TRACE |   󰘍 [1/79] Downloading 193/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250904.csv.gz
# 10:06:03    TRACE |   󰘍 [1/79] Downloading 194/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250905.csv.gz
# 10:06:04    TRACE |   󰘍 [1/79] Downloading 195/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250906.csv.gz
# 10:06:04    TRACE |   󰘍 [1/79] Downloading 196/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250907.csv.gz
# 10:06:04    TRACE |   󰘍 [1/79] Downloading 197/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250908.csv.gz
# 10:06:05    TRACE |   󰘍 [1/79] Downloading 198/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250909.csv.gz
# 10:06:05    TRACE |   󰘍 [1/79] Downloading 199/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250910.csv.gz
# 10:06:05    TRACE |   󰘍 [1/79] Downloading 200/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250911.csv.gz
# 10:06:06    TRACE |   󰘍 [1/79] Downloading 201/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250912.csv.gz
# 10:06:06    TRACE |   󰘍 [1/79] Downloading 202/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250913.csv.gz
# 10:06:06    TRACE |   󰘍 [1/79] Downloading 203/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250914.csv.gz
# 10:06:06    TRACE |   󰘍 [1/79] Downloading 204/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250915.csv.gz
# 10:06:07    TRACE |   󰘍 [1/79] Downloading 205/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250916.csv.gz
# 10:06:07    TRACE |   󰘍 [1/79] Downloading 206/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250917.csv.gz
# 10:06:07    TRACE |   󰘍 [1/79] Downloading 207/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250918.csv.gz
# 10:06:07    TRACE |   󰘍 [1/79] Downloading 208/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250919.csv.gz
# 10:06:08    TRACE |   󰘍 [1/79] Downloading 209/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250920.csv.gz
# 10:06:08    TRACE |   󰘍 [1/79] Downloading 210/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250921.csv.gz
# 10:06:08    TRACE |   󰘍 [1/79] Downloading 211/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250922.csv.gz
# 10:06:09    TRACE |   󰘍 [1/79] Downloading 212/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250923.csv.gz
# 10:06:09    TRACE |   󰘍 [1/79] Downloading 213/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250924.csv.gz
# 10:06:09    TRACE |   󰘍 [1/79] Downloading 214/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250925.csv.gz
# 10:06:09    TRACE |   󰘍 [1/79] Downloading 215/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250926.csv.gz
# 10:06:10    TRACE |   󰘍 [1/79] Downloading 216/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250927.csv.gz
# 10:06:10    TRACE |   󰘍 [1/79] Downloading 217/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250928.csv.gz
# 10:06:10    TRACE |   󰘍 [1/79] Downloading 218/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250929.csv.gz
# 10:06:10    TRACE |   󰘍 [1/79] Downloading 219/287: records/csv.gz/locationid=5627/year=2025/month=09/location-5627-20250930.csv.gz
# 10:06:11    TRACE |   󰘍 [1/79] Downloading 220/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251001.csv.gz
# 10:06:11    TRACE |   󰘍 [1/79] Downloading 221/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251002.csv.gz
# 10:06:11    TRACE |   󰘍 [1/79] Downloading 222/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251003.csv.gz
# 10:06:11    TRACE |   󰘍 [1/79] Downloading 223/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251004.csv.gz
# 10:06:12    TRACE |   󰘍 [1/79] Downloading 224/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251005.csv.gz
# 10:06:12    TRACE |   󰘍 [1/79] Downloading 225/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251006.csv.gz
# 10:06:12    TRACE |   󰘍 [1/79] Downloading 226/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251007.csv.gz
# 10:06:13    TRACE |   󰘍 [1/79] Downloading 227/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251008.csv.gz
# 10:06:13    TRACE |   󰘍 [1/79] Downloading 228/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251009.csv.gz
# 10:06:13    TRACE |   󰘍 [1/79] Downloading 229/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251010.csv.gz
# 10:06:13    TRACE |   󰘍 [1/79] Downloading 230/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251011.csv.gz
# 10:06:14    TRACE |   󰘍 [1/79] Downloading 231/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251012.csv.gz
# 10:06:14    TRACE |   󰘍 [1/79] Downloading 232/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251013.csv.gz
# 10:06:14    TRACE |   󰘍 [1/79] Downloading 233/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251014.csv.gz
# 10:06:14    TRACE |   󰘍 [1/79] Downloading 234/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251015.csv.gz
# 10:06:15    TRACE |   󰘍 [1/79] Downloading 235/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251016.csv.gz
# 10:06:15    TRACE |   󰘍 [1/79] Downloading 236/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251017.csv.gz
# 10:06:15    TRACE |   󰘍 [1/79] Downloading 237/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251018.csv.gz
# 10:06:15    TRACE |   󰘍 [1/79] Downloading 238/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251019.csv.gz
# 10:06:16    TRACE |   󰘍 [1/79] Downloading 239/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251020.csv.gz
# 10:06:16    TRACE |   󰘍 [1/79] Downloading 240/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251021.csv.gz
# 10:06:16    TRACE |   󰘍 [1/79] Downloading 241/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251022.csv.gz
# 10:06:17    TRACE |   󰘍 [1/79] Downloading 242/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251023.csv.gz
# 10:06:17    TRACE |   󰘍 [1/79] Downloading 243/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251024.csv.gz
# 10:06:17    TRACE |   󰘍 [1/79] Downloading 244/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251025.csv.gz
# 10:06:17    TRACE |   󰘍 [1/79] Downloading 245/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251026.csv.gz
# 10:06:18    TRACE |   󰘍 [1/79] Downloading 246/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251027.csv.gz
# 10:06:18    TRACE |   󰘍 [1/79] Downloading 247/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251028.csv.gz
# 10:06:18    TRACE |   󰘍 [1/79] Downloading 248/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251029.csv.gz
# 10:06:18    TRACE |   󰘍 [1/79] Downloading 249/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251030.csv.gz
# 10:06:19    TRACE |   󰘍 [1/79] Downloading 250/287: records/csv.gz/locationid=5627/year=2025/month=10/location-5627-20251031.csv.gz
# 10:06:19    TRACE |   󰘍 [1/79] Downloading 251/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251101.csv.gz
# 10:06:19    TRACE |   󰘍 [1/79] Downloading 252/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251102.csv.gz
# 10:06:20    TRACE |   󰘍 [1/79] Downloading 253/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251103.csv.gz
# 10:06:20    TRACE |   󰘍 [1/79] Downloading 254/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251104.csv.gz
# 10:06:20    TRACE |   󰘍 [1/79] Downloading 255/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251105.csv.gz
# 10:06:21    TRACE |   󰘍 [1/79] Downloading 256/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251106.csv.gz
# 10:06:21    TRACE |   󰘍 [1/79] Downloading 257/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251107.csv.gz
# 10:06:21    TRACE |   󰘍 [1/79] Downloading 258/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251108.csv.gz
# 10:06:21    TRACE |   󰘍 [1/79] Downloading 259/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251109.csv.gz
# 10:06:22    TRACE |   󰘍 [1/79] Downloading 260/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251110.csv.gz
# 10:06:22    TRACE |   󰘍 [1/79] Downloading 261/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251111.csv.gz
# 10:06:21    TRACE |   󰘍 [1/79] Downloading 262/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251112.csv.gz
# 10:06:21    TRACE |   󰘍 [1/79] Downloading 263/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251113.csv.gz
# 10:06:21    TRACE |   󰘍 [1/79] Downloading 264/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251114.csv.gz
# 10:06:22    TRACE |   󰘍 [1/79] Downloading 265/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251115.csv.gz
# 10:06:22    TRACE |   󰘍 [1/79] Downloading 266/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251116.csv.gz
# 10:06:22    TRACE |   󰘍 [1/79] Downloading 267/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251117.csv.gz
# 10:06:22    TRACE |   󰘍 [1/79] Downloading 268/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251118.csv.gz
# 10:06:23    TRACE |   󰘍 [1/79] Downloading 269/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251119.csv.gz
# 10:06:23    TRACE |   󰘍 [1/79] Downloading 270/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251120.csv.gz
# 10:06:23    TRACE |   󰘍 [1/79] Downloading 271/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251121.csv.gz
# 10:06:23    TRACE |   󰘍 [1/79] Downloading 272/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251122.csv.gz
# 10:06:24    TRACE |   󰘍 [1/79] Downloading 273/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251123.csv.gz
# 10:06:24    TRACE |   󰘍 [1/79] Downloading 274/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251124.csv.gz
# 10:06:24    TRACE |   󰘍 [1/79] Downloading 275/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251125.csv.gz
# 10:06:25    TRACE |   󰘍 [1/79] Downloading 276/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251126.csv.gz
# 10:06:25    TRACE |   󰘍 [1/79] Downloading 277/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251127.csv.gz
# 10:06:25    TRACE |   󰘍 [1/79] Downloading 278/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251128.csv.gz
# 10:06:25    TRACE |   󰘍 [1/79] Downloading 279/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251129.csv.gz
# 10:06:26    TRACE |   󰘍 [1/79] Downloading 280/287: records/csv.gz/locationid=5627/year=2025/month=11/location-5627-20251130.csv.gz
# 10:06:26    TRACE |   󰘍 [1/79] Downloading 281/287: records/csv.gz/locationid=5627/year=2025/month=12/location-5627-20251201.csv.gz
# 10:06:26    TRACE |   󰘍 [1/79] Downloading 282/287: records/csv.gz/locationid=5627/year=2025/month=12/location-5627-20251202.csv.gz
# 10:06:27    TRACE |   󰘍 [1/79] Downloading 283/287: records/csv.gz/locationid=5627/year=2025/month=12/location-5627-20251203.csv.gz
# 10:06:27    TRACE |   󰘍 [1/79] Downloading 284/287: records/csv.gz/locationid=5627/year=2025/month=12/location-5627-20251204.csv.gz
# 10:06:27    TRACE |   󰘍 [1/79] Downloading 285/287: records/csv.gz/locationid=5627/year=2025/month=12/location-5627-20251205.csv.gz
# 10:06:27    TRACE |   󰘍 [1/79] Downloading 286/287: records/csv.gz/locationid=5627/year=2025/month=12/location-5627-20251206.csv.gz
# 10:06:28    TRACE |   󰘍 [1/79] Downloading 287/287: records/csv.gz/locationid=5627/year=2025/month=12/location-5627-20251207.csv.gz
# 10:06:28  SUCCESS |  Finished downloading 287 files.
# 10:06:28    DEBUG |  Scanning s3://openaq-data-archive/records/csv.gz/locationid=5630/year=2025
# 10:06:29     INFO |  Found 287 files. Starting downloads...
# 10:06:29    TRACE |   󰘍 [2/79] Downloading 1/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250219.csv.gz
# 10:06:29    TRACE |   󰘍 [2/79] Downloading 2/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250220.csv.gz
# 10:06:29    TRACE |   󰘍 [2/79] Downloading 3/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250221.csv.gz
# 10:06:29    TRACE |   󰘍 [2/79] Downloading 4/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250222.csv.gz
# 10:06:30    TRACE |   󰘍 [2/79] Downloading 5/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250223.csv.gz
# 10:06:30    TRACE |   󰘍 [2/79] Downloading 6/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250224.csv.gz
# 10:06:30    TRACE |   󰘍 [2/79] Downloading 7/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250225.csv.gz
# 10:06:31    TRACE |   󰘍 [2/79] Downloading 8/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250226.csv.gz
# 10:06:31    TRACE |   󰘍 [2/79] Downloading 9/287: records/csv.gz/locationid=5630/year=2025/month=02/location-5630-20250227.csv.gz
# 10:06:31    TRACE |   󰘍 [2/79] Downloading 10/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250304.csv.gz
# 10:06:31    TRACE |   󰘍 [2/79] Downloading 11/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250305.csv.gz
# 10:06:32    TRACE |   󰘍 [2/79] Downloading 12/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250306.csv.gz
# 10:06:32    TRACE |   󰘍 [2/79] Downloading 13/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250307.csv.gz
# 10:06:32    TRACE |   󰘍 [2/79] Downloading 14/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250308.csv.gz
# 10:06:33    TRACE |   󰘍 [2/79] Downloading 15/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250309.csv.gz
# 10:06:33    TRACE |   󰘍 [2/79] Downloading 16/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250310.csv.gz
# 10:06:33    TRACE |   󰘍 [2/79] Downloading 17/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250311.csv.gz
# 10:06:33    TRACE |   󰘍 [2/79] Downloading 18/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250312.csv.gz
# 10:06:34    TRACE |   󰘍 [2/79] Downloading 19/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250313.csv.gz
# 10:06:34    TRACE |   󰘍 [2/79] Downloading 20/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250314.csv.gz
# 10:06:34    TRACE |   󰘍 [2/79] Downloading 21/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250315.csv.gz
# 10:06:35    TRACE |   󰘍 [2/79] Downloading 22/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250316.csv.gz
# 10:06:35    TRACE |   󰘍 [2/79] Downloading 23/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250317.csv.gz
# 10:06:35    TRACE |   󰘍 [2/79] Downloading 24/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250318.csv.gz
# 10:06:35    TRACE |   󰘍 [2/79] Downloading 25/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250319.csv.gz
# 10:06:36    TRACE |   󰘍 [2/79] Downloading 26/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250320.csv.gz
# 10:06:36    TRACE |   󰘍 [2/79] Downloading 27/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250321.csv.gz
# 10:06:36    TRACE |   󰘍 [2/79] Downloading 28/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250322.csv.gz
# 10:06:36    TRACE |   󰘍 [2/79] Downloading 29/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250323.csv.gz
# 10:06:37    TRACE |   󰘍 [2/79] Downloading 30/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250324.csv.gz
# 10:06:37    TRACE |   󰘍 [2/79] Downloading 31/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250325.csv.gz
# 10:06:37    TRACE |   󰘍 [2/79] Downloading 32/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250326.csv.gz
# 10:06:38    TRACE |   󰘍 [2/79] Downloading 33/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250327.csv.gz
# 10:06:38    TRACE |   󰘍 [2/79] Downloading 34/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250328.csv.gz
# 10:06:38    TRACE |   󰘍 [2/79] Downloading 35/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250329.csv.gz
# 10:06:38    TRACE |   󰘍 [2/79] Downloading 36/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250330.csv.gz
# 10:06:39    TRACE |   󰘍 [2/79] Downloading 37/287: records/csv.gz/locationid=5630/year=2025/month=03/location-5630-20250331.csv.gz
# 10:06:39    TRACE |   󰘍 [2/79] Downloading 38/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250401.csv.gz
# 10:06:39    TRACE |   󰘍 [2/79] Downloading 39/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250402.csv.gz
# 10:06:40    TRACE |   󰘍 [2/79] Downloading 40/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250403.csv.gz
# 10:06:40    TRACE |   󰘍 [2/79] Downloading 41/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250404.csv.gz
# 10:06:40    TRACE |   󰘍 [2/79] Downloading 42/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250405.csv.gz
# 10:06:40    TRACE |   󰘍 [2/79] Downloading 43/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250406.csv.gz
# 10:06:41    TRACE |   󰘍 [2/79] Downloading 44/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250407.csv.gz
# 10:06:41    TRACE |   󰘍 [2/79] Downloading 45/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250408.csv.gz
# 10:06:41    TRACE |   󰘍 [2/79] Downloading 46/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250409.csv.gz
# 10:06:41    TRACE |   󰘍 [2/79] Downloading 47/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250411.csv.gz
# 10:06:42    TRACE |   󰘍 [2/79] Downloading 48/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250412.csv.gz
# 10:06:42    TRACE |   󰘍 [2/79] Downloading 49/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250413.csv.gz
# 10:06:42    TRACE |   󰘍 [2/79] Downloading 50/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250414.csv.gz
# 10:06:43    TRACE |   󰘍 [2/79] Downloading 51/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250415.csv.gz
# 10:06:43    TRACE |   󰘍 [2/79] Downloading 52/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250416.csv.gz
# 10:06:43    TRACE |   󰘍 [2/79] Downloading 53/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250417.csv.gz
# 10:06:44    TRACE |   󰘍 [2/79] Downloading 54/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250418.csv.gz
# 10:06:44    TRACE |   󰘍 [2/79] Downloading 55/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250419.csv.gz
# 10:06:44    TRACE |   󰘍 [2/79] Downloading 56/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250420.csv.gz
# 10:06:44    TRACE |   󰘍 [2/79] Downloading 57/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250421.csv.gz
# 10:06:45    TRACE |   󰘍 [2/79] Downloading 58/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250422.csv.gz
# 10:06:45    TRACE |   󰘍 [2/79] Downloading 59/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250423.csv.gz
# 10:06:45    TRACE |   󰘍 [2/79] Downloading 60/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250424.csv.gz
# 10:06:46    TRACE |   󰘍 [2/79] Downloading 61/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250425.csv.gz
# 10:06:46    TRACE |   󰘍 [2/79] Downloading 62/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250426.csv.gz
# 10:06:46    TRACE |   󰘍 [2/79] Downloading 63/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250427.csv.gz
# 10:06:46    TRACE |   󰘍 [2/79] Downloading 64/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250428.csv.gz
# 10:06:47    TRACE |   󰘍 [2/79] Downloading 65/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250429.csv.gz
# 10:06:47    TRACE |   󰘍 [2/79] Downloading 66/287: records/csv.gz/locationid=5630/year=2025/month=04/location-5630-20250430.csv.gz
# 10:06:47    TRACE |   󰘍 [2/79] Downloading 67/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250501.csv.gz
# 10:06:47    TRACE |   󰘍 [2/79] Downloading 68/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250502.csv.gz
# 10:06:48    TRACE |   󰘍 [2/79] Downloading 69/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250503.csv.gz
# 10:06:48    TRACE |   󰘍 [2/79] Downloading 70/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250504.csv.gz
# 10:06:48    TRACE |   󰘍 [2/79] Downloading 71/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250505.csv.gz
# 10:06:48    TRACE |   󰘍 [2/79] Downloading 72/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250506.csv.gz
# 10:06:49    TRACE |   󰘍 [2/79] Downloading 73/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250507.csv.gz
# 10:06:49    TRACE |   󰘍 [2/79] Downloading 74/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250508.csv.gz
# 10:06:49    TRACE |   󰘍 [2/79] Downloading 75/287: records/csv.gz/locationid=5630/year=2025/month=05/location-5630-20250509.csv.gz
# ...
# 11:01:44    TRACE |   󰘍 [76/79] Downloading 6/46: records/csv.gz/locationid=6105800/year=2025/month=10/location-6105800-20251028.csv.gz
# 11:01:44    TRACE |   󰘍 [76/79] Downloading 7/46: records/csv.gz/locationid=6105800/year=2025/month=10/location-6105800-20251029.csv.gz
# 11:01:44    TRACE |   󰘍 [76/79] Downloading 8/46: records/csv.gz/locationid=6105800/year=2025/month=10/location-6105800-20251030.csv.gz
# 11:01:45    TRACE |   󰘍 [76/79] Downloading 9/46: records/csv.gz/locationid=6105800/year=2025/month=10/location-6105800-20251031.csv.gz
# 11:01:45    TRACE |   󰘍 [76/79] Downloading 10/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251101.csv.gz
# 11:01:45    TRACE |   󰘍 [76/79] Downloading 11/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251102.csv.gz
# 11:01:45    TRACE |   󰘍 [76/79] Downloading 12/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251103.csv.gz
# 11:01:46    TRACE |   󰘍 [76/79] Downloading 13/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251104.csv.gz
# 11:01:46    TRACE |   󰘍 [76/79] Downloading 14/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251105.csv.gz
# 11:01:46    TRACE |   󰘍 [76/79] Downloading 15/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251106.csv.gz
# 11:01:47    TRACE |   󰘍 [76/79] Downloading 16/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251107.csv.gz
# 11:01:47    TRACE |   󰘍 [76/79] Downloading 17/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251108.csv.gz
# 11:01:47    TRACE |   󰘍 [76/79] Downloading 18/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251109.csv.gz
# 11:01:47    TRACE |   󰘍 [76/79] Downloading 19/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251110.csv.gz
# 11:01:48    TRACE |   󰘍 [76/79] Downloading 20/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251111.csv.gz
# 11:01:48    TRACE |   󰘍 [76/79] Downloading 21/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251112.csv.gz
# 11:01:48    TRACE |   󰘍 [76/79] Downloading 22/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251113.csv.gz
# 11:01:48    TRACE |   󰘍 [76/79] Downloading 23/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251114.csv.gz
# 11:01:48    TRACE |   󰘍 [76/79] Downloading 24/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251115.csv.gz
# 11:01:49    TRACE |   󰘍 [76/79] Downloading 25/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251116.csv.gz
# 11:01:49    TRACE |   󰘍 [76/79] Downloading 26/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251117.csv.gz
# 11:01:49    TRACE |   󰘍 [76/79] Downloading 27/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251118.csv.gz
# 11:01:49    TRACE |   󰘍 [76/79] Downloading 28/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251119.csv.gz
# 11:01:50    TRACE |   󰘍 [76/79] Downloading 29/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251120.csv.gz
# 11:01:50    TRACE |   󰘍 [76/79] Downloading 30/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251121.csv.gz
# 11:01:50    TRACE |   󰘍 [76/79] Downloading 31/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251122.csv.gz
# 11:01:50    TRACE |   󰘍 [76/79] Downloading 32/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251123.csv.gz
# 11:01:51    TRACE |   󰘍 [76/79] Downloading 33/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251124.csv.gz
# 11:01:51    TRACE |   󰘍 [76/79] Downloading 34/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251125.csv.gz
# 11:01:51    TRACE |   󰘍 [76/79] Downloading 35/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251126.csv.gz
# 11:01:51    TRACE |   󰘍 [76/79] Downloading 36/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251127.csv.gz
# 11:01:52    TRACE |   󰘍 [76/79] Downloading 37/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251128.csv.gz
# 11:01:52    TRACE |   󰘍 [76/79] Downloading 38/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251129.csv.gz
# 11:01:52    TRACE |   󰘍 [76/79] Downloading 39/46: records/csv.gz/locationid=6105800/year=2025/month=11/location-6105800-20251130.csv.gz
# 11:01:52    TRACE |   󰘍 [76/79] Downloading 40/46: records/csv.gz/locationid=6105800/year=2025/month=12/location-6105800-20251201.csv.gz
# 11:01:53    TRACE |   󰘍 [76/79] Downloading 41/46: records/csv.gz/locationid=6105800/year=2025/month=12/location-6105800-20251202.csv.gz
# 11:01:53    TRACE |   󰘍 [76/79] Downloading 42/46: records/csv.gz/locationid=6105800/year=2025/month=12/location-6105800-20251203.csv.gz
# 11:01:53    TRACE |   󰘍 [76/79] Downloading 43/46: records/csv.gz/locationid=6105800/year=2025/month=12/location-6105800-20251204.csv.gz
# 11:01:53    TRACE |   󰘍 [76/79] Downloading 44/46: records/csv.gz/locationid=6105800/year=2025/month=12/location-6105800-20251205.csv.gz
# 11:01:54    TRACE |   󰘍 [76/79] Downloading 45/46: records/csv.gz/locationid=6105800/year=2025/month=12/location-6105800-20251206.csv.gz
# 11:01:54    TRACE |   󰘍 [76/79] Downloading 46/46: records/csv.gz/locationid=6105800/year=2025/month=12/location-6105800-20251207.csv.gz
# 11:01:54  SUCCESS |  Finished downloading 46 files.
# 11:01:54    DEBUG |  Scanning s3://openaq-data-archive/records/csv.gz/locationid=6119272/year=2025
# 11:01:55     INFO |  Found 34 files. Starting downloads...
# 11:01:55    TRACE |   󰘍 [77/79] Downloading 1/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251104.csv.gz
# 11:01:55    TRACE |   󰘍 [77/79] Downloading 2/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251105.csv.gz
# 11:01:55    TRACE |   󰘍 [77/79] Downloading 3/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251106.csv.gz
# 11:01:55    TRACE |   󰘍 [77/79] Downloading 4/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251107.csv.gz
# 11:01:56    TRACE |   󰘍 [77/79] Downloading 5/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251108.csv.gz
# 11:01:56    TRACE |   󰘍 [77/79] Downloading 6/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251109.csv.gz
# 11:01:56    TRACE |   󰘍 [77/79] Downloading 7/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251110.csv.gz
# 11:01:56    TRACE |   󰘍 [77/79] Downloading 8/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251111.csv.gz
# 11:01:57    TRACE |   󰘍 [77/79] Downloading 9/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251112.csv.gz
# 11:01:57    TRACE |   󰘍 [77/79] Downloading 10/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251113.csv.gz
# 11:01:57    TRACE |   󰘍 [77/79] Downloading 11/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251114.csv.gz
# 11:01:57    TRACE |   󰘍 [77/79] Downloading 12/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251115.csv.gz
# 11:01:57    TRACE |   󰘍 [77/79] Downloading 13/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251116.csv.gz
# 11:01:58    TRACE |   󰘍 [77/79] Downloading 14/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251117.csv.gz
# 11:01:58    TRACE |   󰘍 [77/79] Downloading 15/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251118.csv.gz
# 11:01:58    TRACE |   󰘍 [77/79] Downloading 16/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251119.csv.gz
# 11:01:58    TRACE |   󰘍 [77/79] Downloading 17/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251120.csv.gz
# 11:01:59    TRACE |   󰘍 [77/79] Downloading 18/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251121.csv.gz
# 11:01:59    TRACE |   󰘍 [77/79] Downloading 19/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251122.csv.gz
# 11:01:59    TRACE |   󰘍 [77/79] Downloading 20/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251123.csv.gz
# 11:01:59    TRACE |   󰘍 [77/79] Downloading 21/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251124.csv.gz
# 11:02:00    TRACE |   󰘍 [77/79] Downloading 22/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251125.csv.gz
# 11:02:00    TRACE |   󰘍 [77/79] Downloading 23/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251126.csv.gz
# 11:02:00    TRACE |   󰘍 [77/79] Downloading 24/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251127.csv.gz
# 11:02:00    TRACE |   󰘍 [77/79] Downloading 25/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251128.csv.gz
# 11:02:01    TRACE |   󰘍 [77/79] Downloading 26/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251129.csv.gz
# 11:02:01    TRACE |   󰘍 [77/79] Downloading 27/34: records/csv.gz/locationid=6119272/year=2025/month=11/location-6119272-20251130.csv.gz
# 11:02:01    TRACE |   󰘍 [77/79] Downloading 28/34: records/csv.gz/locationid=6119272/year=2025/month=12/location-6119272-20251201.csv.gz
# 11:02:01    TRACE |   󰘍 [77/79] Downloading 29/34: records/csv.gz/locationid=6119272/year=2025/month=12/location-6119272-20251202.csv.gz
# 11:02:02    TRACE |   󰘍 [77/79] Downloading 30/34: records/csv.gz/locationid=6119272/year=2025/month=12/location-6119272-20251203.csv.gz
# 11:02:02    TRACE |   󰘍 [77/79] Downloading 31/34: records/csv.gz/locationid=6119272/year=2025/month=12/location-6119272-20251204.csv.gz
# 11:02:02    TRACE |   󰘍 [77/79] Downloading 32/34: records/csv.gz/locationid=6119272/year=2025/month=12/location-6119272-20251205.csv.gz
# 11:02:03    TRACE |   󰘍 [77/79] Downloading 33/34: records/csv.gz/locationid=6119272/year=2025/month=12/location-6119272-20251206.csv.gz
# 11:02:03    TRACE |   󰘍 [77/79] Downloading 34/34: records/csv.gz/locationid=6119272/year=2025/month=12/location-6119272-20251207.csv.gz
# 11:02:03  SUCCESS |  Finished downloading 34 files.
# 11:02:03    DEBUG |  Scanning s3://openaq-data-archive/records/csv.gz/locationid=6125489/year=2025
# 11:02:03     INFO |  Found 27 files. Starting downloads...
# 11:02:03    TRACE |   󰘍 [78/79] Downloading 1/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251110.csv.gz
# 11:02:04    TRACE |   󰘍 [78/79] Downloading 2/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251111.csv.gz
# 11:02:04    TRACE |   󰘍 [78/79] Downloading 3/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251112.csv.gz
# 11:02:04    TRACE |   󰘍 [78/79] Downloading 4/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251113.csv.gz
# 11:02:04    TRACE |   󰘍 [78/79] Downloading 5/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251114.csv.gz
# 11:02:04    TRACE |   󰘍 [78/79] Downloading 6/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251115.csv.gz
# 11:02:04    TRACE |   󰘍 [78/79] Downloading 7/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251116.csv.gz
# 11:02:04    TRACE |   󰘍 [78/79] Downloading 8/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251117.csv.gz
# 11:02:05    TRACE |   󰘍 [78/79] Downloading 9/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251118.csv.gz
# 11:02:05    TRACE |   󰘍 [78/79] Downloading 10/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251119.csv.gz
# 11:02:05    TRACE |   󰘍 [78/79] Downloading 11/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251120.csv.gz
# 11:02:05    TRACE |   󰘍 [78/79] Downloading 12/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251121.csv.gz
# 11:02:06    TRACE |   󰘍 [78/79] Downloading 13/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251122.csv.gz
# 11:02:06    TRACE |   󰘍 [78/79] Downloading 14/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251124.csv.gz
# 11:02:06    TRACE |   󰘍 [78/79] Downloading 15/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251125.csv.gz
# 11:02:06    TRACE |   󰘍 [78/79] Downloading 16/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251126.csv.gz
# 11:02:07    TRACE |   󰘍 [78/79] Downloading 17/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251127.csv.gz
# 11:02:07    TRACE |   󰘍 [78/79] Downloading 18/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251128.csv.gz
# 11:02:07    TRACE |   󰘍 [78/79] Downloading 19/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251129.csv.gz
# 11:02:07    TRACE |   󰘍 [78/79] Downloading 20/27: records/csv.gz/locationid=6125489/year=2025/month=11/location-6125489-20251130.csv.gz
# 11:02:08    TRACE |   󰘍 [78/79] Downloading 21/27: records/csv.gz/locationid=6125489/year=2025/month=12/location-6125489-20251201.csv.gz
# 11:02:08    TRACE |   󰘍 [78/79] Downloading 22/27: records/csv.gz/locationid=6125489/year=2025/month=12/location-6125489-20251202.csv.gz
# 11:02:08    TRACE |   󰘍 [78/79] Downloading 23/27: records/csv.gz/locationid=6125489/year=2025/month=12/location-6125489-20251203.csv.gz
# 11:02:08    TRACE |   󰘍 [78/79] Downloading 24/27: records/csv.gz/locationid=6125489/year=2025/month=12/location-6125489-20251204.csv.gz
# 11:02:09    TRACE |   󰘍 [78/79] Downloading 25/27: records/csv.gz/locationid=6125489/year=2025/month=12/location-6125489-20251205.csv.gz
# 11:02:09    TRACE |   󰘍 [78/79] Downloading 26/27: records/csv.gz/locationid=6125489/year=2025/month=12/location-6125489-20251206.csv.gz
# 11:02:09    TRACE |   󰘍 [78/79] Downloading 27/27: records/csv.gz/locationid=6125489/year=2025/month=12/location-6125489-20251207.csv.gz
# 11:02:09  SUCCESS |  Finished downloading 27 files.
# 11:02:09    DEBUG |  Scanning s3://openaq-data-archive/records/csv.gz/locationid=6145551/year=2025
# 11:02:10     INFO |  Found 10 files. Starting downloads...
# 11:02:10    TRACE |   󰘍 [79/79] Downloading 1/10: records/csv.gz/locationid=6145551/year=2025/month=11/location-6145551-20251128.csv.gz
# 11:02:10    TRACE |   󰘍 [79/79] Downloading 2/10: records/csv.gz/locationid=6145551/year=2025/month=11/location-6145551-20251129.csv.gz
# 11:02:10    TRACE |   󰘍 [79/79] Downloading 3/10: records/csv.gz/locationid=6145551/year=2025/month=11/location-6145551-20251130.csv.gz
# 11:02:10    TRACE |   󰘍 [79/79] Downloading 4/10: records/csv.gz/locationid=6145551/year=2025/month=12/location-6145551-20251201.csv.gz
# 11:02:11    TRACE |   󰘍 [79/79] Downloading 5/10: records/csv.gz/locationid=6145551/year=2025/month=12/location-6145551-20251202.csv.gz
# 11:02:11    TRACE |   󰘍 [79/79] Downloading 6/10: records/csv.gz/locationid=6145551/year=2025/month=12/location-6145551-20251203.csv.gz
# 11:02:11    TRACE |   󰘍 [79/79] Downloading 7/10: records/csv.gz/locationid=6145551/year=2025/month=12/location-6145551-20251204.csv.gz
# 11:02:11    TRACE |   󰘍 [79/79] Downloading 8/10: records/csv.gz/locationid=6145551/year=2025/month=12/location-6145551-20251205.csv.gz
# 11:02:12    TRACE |   󰘍 [79/79] Downloading 9/10: records/csv.gz/locationid=6145551/year=2025/month=12/location-6145551-20251206.csv.gz
# 11:02:12    TRACE |   󰘍 [79/79] Downloading 10/10: records/csv.gz/locationid=6145551/year=2025/month=12/location-6145551-20251207.csv.gz
# 11:02:12  SUCCESS |  Finished downloading 10 files.

# %%
# BASELINE: Retrieve the same data using the API (hourly mean)

location_id = 235
sensor_id = 12235605

res = request_openaq(
    f"https://api.openaq.org/v3/sensors/{sensor_id}/measurements/hourly",
    {
        "datetime_from": "2025-08-21 00:45:00+05:30",
        "datetime_to": "2025-08-21 04:00:00+05:30",
        "limit": 1000,
        "pages": 1,
    },
)

baseline_measurements = res["results"]
baseline_measurements["sensor_id"] = sensor_id
baseline_measurements["location_id"] = location_id

# %%
# 1. Create "chunks" of CSVs so avoid memory overhead.
# 2. Add a project name
import glob


def create_dataframe_from_csv_files(
    filename: str,
    csv_filenames: list[str] | None = None,
    parent_path: str = "",
    **kwargs,
) -> None:
    """Create a single DataFrame by concatenating multiple CSV files."""

    OUTPUT_CSV_DIR = os.path.join(config.DATA_PATH, "csv")
    os.makedirs(OUTPUT_CSV_DIR, exist_ok=True)

    print(f"filename: {filename}")
    print(f"parent_path: {parent_path}")

    input_path = parent_path
    output_file = filename + ".csv"
    output_path = os.path.join(OUTPUT_CSV_DIR, output_file)

    # print(csv_filenames)
    # return
    if csv_filenames is not None:
        print(f"Using provided list of {len(csv_filenames)} CSV files.")
        all_files = [os.path.join(input_path, f) for f in csv_filenames]
    else:

        all_files = glob.glob(os.path.join(input_path, "*.csv"))

    # print(f"glob path: {os.path.join(input_path, '*.csv')}")
    print(f"Found {len(all_files)} files.")

    # 2. Iterate through files and write to the output file
    for i, csv_path in enumerate(all_files):
        # Read the file
        try:
            df = pd.read_csv(csv_path)
        except Exception as e:
            print(f"Error reading {csv_path}: {e}. Skipping.")
            continue  # Skip to the next file

        if i == 0:
            # First file: Write the header row
            df.to_csv(output_path, mode="w", index=False, header=True)
        else:
            # Subsequent files: Append without the header row
            df.to_csv(output_path, mode="a", index=False, header=False)

    return None

create_dataframe_from_csv_files("new_delhi_235_20250821", csv_filenames=["location-235-20250821.csv"], parent_path=config.DATA_PATH / "aws")

df_test = pd.read_csv(config.DATA_PATH / "csv" / "new_delhi_235_20250821.csv")
# df_test.sort_values(by="datetime")

df_test["datetime"] = pd.to_datetime(df_test["datetime"])
df_test = df_test.sort_values(by=["sensors_id", "datetime"])


# Filter measurements for a specific date (e.g., 2016-11-03)
# date_mask = df_test["sensor_id"] == 12235605
# df_test_filtered= df_test[date_mask][["location_id", "sensor_id", "parameter.id", "datetimeFrom_local", "datetimeTo_local", "period.interval", "value"]]
# display(df_test_filtered)




# display(df_test[["location_id", "sensors_id", "datetime", "parameter", "units", "value"]].head(10))
display(baseline_measurements[["location_id", "sensor_id", "period.datetimeFrom.local", "parameter.name", "parameter.units", "value"]].head(10))
        
# GEMINI

# 2. Set 'datetime' as the index. This is necessary for resampling.
df_test = df_test.set_index('datetime')

# Columns to aggregate by (these are the non-time-series columns for a single sensor's hourly mean)
groupby_cols = ['location_id', 'sensors_id', 'location', 'parameter', 'units']
# Columns to keep which are not aggregated (e.g. lat, lon). We'll take the first non-null value for these in each group.
other_cols = ['lat', 'lon']

# 3. Define the aggregation dictionary
agg_dict = {'value': 'mean'} # Calculate the mean of 'value'
for col in other_cols:
    agg_dict[col] = 'first' # Take the first value for static columns (lat, lon)

hourly_aggregated_df = df_test.groupby(groupby_cols).resample('h').agg(agg_dict)
hourly_aggregated_df = hourly_aggregated_df.reset_index().sort_values(by=["sensors_id", "datetime"])
display(hourly_aggregated_df.head())
# END


# display(df_test["sensors_id"].value_counts())


# df_test[["location_id", "sensors_id", "datetime", "parameter", "units", "value"]].head(10)

# df_test.info()
# df = create_dataframe_from_csv_files(
#     "new_delhi", parent_path=config.DATA_PATH / "aws"
# )
# Out:
# filename: new_delhi_235_20250821
# parent_path: /home/deniscck/code/denis-cck/openaq_anomaly_prediction/data/aws
# Using provided list of 1 CSV files.
# Found 1 files.
#    location_id  sensor_id  period.datetimeFrom.local parameter.name parameter.units  value
# 0          235   12235605  2025-08-21T00:00:00+05:30             co             ppb   1.45
# 1          235   12235605  2025-08-21T01:00:00+05:30             co             ppb   1.43
# 2          235   12235605  2025-08-21T02:00:00+05:30             co             ppb   1.36
# 3          235   12235605  2025-08-21T03:00:00+05:30             co             ppb   1.46
#    location_id  sensors_id                               location parameter units                  datetime  value        lat        lon
# 0          235    12235605  Anand Vihar, New Delhi - DPCC-3379575        co   ppb 2025-08-21 00:00:00+05:30  1.450  28.646835  77.316032
# 1          235    12235605  Anand Vihar, New Delhi - DPCC-3379575        co   ppb 2025-08-21 01:00:00+05:30  1.435  28.646835  77.316032
# 2          235    12235605  Anand Vihar, New Delhi - DPCC-3379575        co   ppb 2025-08-21 02:00:00+05:30  1.410  28.646835  77.316032
# 3          235    12235605  Anand Vihar, New Delhi - DPCC-3379575        co   ppb 2025-08-21 03:00:00+05:30  1.400  28.646835  77.316032
# 4          235    12235605  Anand Vihar, New Delhi - DPCC-3379575        co   ppb 2025-08-21 04:00:00+05:30  1.625  28.646835  77.316032

# %%
df = create_dataframe_from_csv_files(csv_files, path=config.DATA_PATH / "aws")
# df.to_csv(config.DATA_PATH / "all_newdelhi_2025.csv", index=True)
# Out:
# *.csv

# %%
# Out:
# filename:
# parent_path: /home/deniscck/code/denis-cck/openaq_anomaly_prediction/data/aws
# glob path: /home/deniscck/code/denis-cck/openaq_anomaly_prediction/data/aws/*.csv
# Found 17495 files.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6992/3244321729.py in ?()
# ----> 1 df = create_dataframe_from_csv_files("new_delhi_235_20250821", csv_filenames=["location-235-20250821.csv"], parent_path=config.DATA_PATH / "aws")
#
# /tmp/ipykernel_6992/3561593106.py in ?(csv_file_paths, filename, parent_path, **kwargs)
#      37             # First file: Write the header row
#      38             df.to_csv(output_path, mode='w', index=False, header=True)
#      39         else:
#      40             # Subsequent files: Append without the header row
# ---> 41             df.to_csv(output_path, mode='a', index=False, header=False)
#      42
#      43     # df_list = []
#      44     # for csv_file in csv_file_paths:
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     329                     msg.format(arguments=_format_argument_list(allow_args)),
#     330                     FutureWarning,
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3985             float_format=float_format,
#    3986             decimal=decimal,
#    3987         )
#    3988
# -> 3989         return DataFrameRenderer(formatter).to_csv(
#    3990             path_or_buf,
#    3991             lineterminator=lineterminator,
#    3992             sep=sep,
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/io/formats/format.py in ?(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1010             escapechar=escapechar,
#    1011             storage_options=storage_options,
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#    1017             assert isinstance(path_or_buf, StringIO)
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/io/formats/csvs.py in ?(self)
#     266                 escapechar=self.escapechar,
#     267                 quotechar=self.quotechar,
#     268             )
#     269
# --> 270             self._save()
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/io/formats/csvs.py in ?(self)
#     272     def _save(self) -> None:
#     273         if self._need_to_save_header:
#     274             self._save_header()
# --> 275         self._save_body()
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/io/formats/csvs.py in ?(self)
#     309             start_i = i * self.chunksize
#     310             end_i = min(start_i + self.chunksize, nrows)
#     311             if start_i >= end_i:
#     312                 break
# --> 313             self._save_chunk(start_i, end_i)
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/io/formats/csvs.py in ?(self, start_i, end_i)
#     317         slicer = slice(start_i, end_i)
#     318         df = self.obj.iloc[slicer]
#     319
#     320         res = df._get_values_for_csv(**self._number_format)
# --> 321         data = list(res._iter_column_arrays())
#     322
#     323         ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
#     324         libwriters.write_csv_rows(
#
# ~/.pyenv/versions/openaq-anomaly-prediction/lib/python3.12/site-packages/pandas/core/frame.py in ?(self)
# -> 4038     def _iter_column_arrays(self) -> Iterator[ArrayLike]:
#    4039         """
#    4040         Iterate over the arrays of all columns in order.
#    4041         This returns the values as stored in the Block (ndarray or ExtensionArray).
#
# KeyboardInterrupt:
